# %% [markdown]
# # Leave One Country Out vs Single country

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import pickle
import os
import gc
import warnings
from collections import defaultdict

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Bidirectional, Input
from tensorflow.keras.layers import Conv1D, Flatten, RepeatVector, TimeDistributed
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model

warnings.filterwarnings("ignore")

# %%
### Configuration
TARGET_VARIABLES = ['co2', 'gdp', 'primary_energy_consumption']
N_STEPS_IN = 5
N_STEPS_OUT = 3
# Setting test size as 9 samples
TEST_SAMPLES = 9
MAX_LAGS = 4

G20_COUNTRIES = [
    'United States', 'China', 'Japan', 'Germany', 
    'United Kingdom', 'France', 'Italy', 'Canada',
    'Brazil', 'Russia', 'India', 'Australia', 
    'Mexico', 'Indonesia', 'Turkey', 'Saudi Arabia',
    'South Africa', 'Argentina', 'South Korea'
]

FEATURES = [
    'fossil_fuel_consumption', 'energy_per_capita',
    'electricity_generation', 'population',
    'nuclear_consumption', 'renewables_consumption'
]

DEVELOPED_COUNTRIES = [
    'United States', 'Japan', 'Germany', 'United Kingdom',
    'France', 'Italy', 'Canada', 'Australia', 'South Korea'
]

DEVELOPING_COUNTRIES = [
    'China', 'Brazil', 'Russia', 'India', 'Mexico', 'Indonesia',
    'Turkey', 'Saudi Arabia', 'South Africa', 'Argentina'
]

# %% [markdown]
# ### Utility Functions

# %%
def clear_memory():
    tf.keras.backend.clear_session()
    gc.collect()

# %%
def rmse(y_pred, y_actual):
    return np.sqrt(mean_squared_error(y_actual, y_pred))

# %%
def mase(y_actual, y_pred, period=1):

    mae_forecast = mean_absolute_error(y_actual, y_pred)
    
    # MAE of naive forecast
    naive_forecast = y_actual[:-period] if period > 0 else y_actual[:-1]
    actual_for_naive = y_actual[period:] if period > 0 else y_actual[1:]
    
    if len(naive_forecast) == 0:
        return np.nan
    
    mae_naive = mean_absolute_error(actual_for_naive, naive_forecast)
    
    if mae_naive == 0:
        return 0 if mae_forecast == 0 else np.inf
    
    return mae_forecast / mae_naive

# %%
def pct_change_features(data):
    """
    This is to convert the series into the percentage change from the previous time step
    -> It will lead the data more stationary
    Avoiding NaN in the first row
    """
    data = data.copy()

    # Storing the original values for denormalisation
    original_values = {}

    # For each feature, calculate pct_change with lag1
    for feature in FEATURES + TARGET_VARIABLES:
        if feature in data.columns:
            # Store original values
            data[f'{feature}_original'] = data[feature].values.copy()
            
            # pct_change
            if f'{feature}_lag1' in data.columns:
                lag1_values = data[f'{feature}_lag1'].values
                current_values = data[feature].values

                # Create mask for non-zero lag values
                non_zero_mask = lag1_values != 0
                pct_change = np.zeros_like(current_values)
            
                # Calculate pct change only where lag1 is non-zero (curr - lag1) / lag1
                pct_change[non_zero_mask] = (current_values[non_zero_mask] - lag1_values[non_zero_mask]) / lag1_values[non_zero_mask]
                
                data[f'{feature}_pct'] = pct_change
    
    return data

# %%
def denormalise_pct_change(pct_preds, last_actual_value):
    """
    Conver pct_change preds back to the original scale
    value_t = value_{t-1} * (1 + pct_change_t)
    """
    actual_values = []
    curr_val = last_actual_value
    
    for pct in pct_preds:
        next_value = curr_val * (1 + pct)
        actual_values.append(next_value)
        curr_val = next_value
    
    return np.array(actual_values)

# %%
def prepare_features(data, features, target, use_lags=True):
    """
    Preparing feature matrix with lag features and pct changes
    """
    feature_cols = []

    all_features = features.copy()
    if target not in all_features:
        all_features.append(target)

    for feature in all_features:
        # Use the original column
        if feature in data.columns:
            feature_cols.append(feature)
        # Or use the _pct column if it exists
        elif f'{feature}_pct' in data.columns:
            feature_cols.append(f'{feature}_pct')

        # Lag features
        if use_lags:
            for lag in range(1, 5):
                lag_col = f'{feature}_lag{lag}'

                if lag_col in data.columns:
                    # Calculate pct change for lag features
                    if lag < 4:
                        next_lag = f'{feature}_lag{lag+1}'
                        if next_lag in data.columns:
                            lag_values = data[lag_col].values
                            next_lag_values = data[next_lag].values
                            
                            non_zero_mask = next_lag_values != 0
                            pct_lag = np.zeros_like(lag_values)
                            pct_lag[non_zero_mask] = (lag_values[non_zero_mask] - next_lag_values[non_zero_mask]) / next_lag_values[non_zero_mask]
                            
                            pct_lag_col = f'{feature}_lag{lag}_pct'
                            data[pct_lag_col] = pct_lag
                            feature_cols.append(pct_lag_col)
    
    if f'{target}_pct' in data.columns:
        target_col = f'{target}_pct'
    else:
        target_col = target
    
    return data, feature_cols, target_col

# %% [markdown]
# ### Data Load

# %%
def load_data(save_dir='data_export'):
    lag_path = os.path.join(save_dir, 'lag_df_1965.pkl')
    lag_df = pd.read_pickle(lag_path)
    print(f"Data Shape: {lag_df.shape}")
    return lag_df

# %% [markdown]
# ### Model builds

# %%
def build_lstm(input_shape, output_shape, hidden=32):
    model = Sequential([
        LSTM(hidden, activation='relu', input_shape=input_shape, kernel_regularizer=l2(0.01)),
        Dense(output_shape)
    ])
    model.compile(optimizer=Adam(learning_rate=0.01), loss='mse', metrics=['mae'])
    return model

# %%
def build_bilstm(input_shape, output_shape, hidden=16):
    model = Sequential([
        Bidirectional(LSTM(hidden, activation='relu', kernel_regularizer=l2(0.001), recurrent_regularizer=l2(0.01)),
                      input_shape=input_shape),
        Dense(output_shape)
    ])
    model.compile(optimizer=Adam(learning_rate=0.01), loss='mse', metrics=['mae'])
    return model

# %%
def build_edlstm(input_shape, output_shape, hidden=16):
    model = Sequential([
        LSTM(hidden, activation='relu', input_shape=input_shape, kernel_regularizer=l2(0.01)),
        RepeatVector(output_shape),
        LSTM(hidden, activation='relu', return_sequences=True, kernel_regularizer=l2(0.01)),
        TimeDistributed(Dense(1))
    ])
    model.compile(optimizer=Adam(learning_rate=0.01), loss='mse', metrics=['mae'])
    return model

# %%
def build_cnn(input_shape, output_shape, filters=32, hidden=16):
    model = Sequential([
        Conv1D(filters=filters, kernel_size=3, activation='relu', input_shape=input_shape, padding='same', kernel_regularizer=l2(0.01)),
        Flatten(),
        Dense(hidden, activation='relu', kernel_regularizer=l2(0.01)),
        Dense(output_shape)
    ])
    model.compile(optimizer=Adam(learning_rate=0.01), loss='mse', metrics=['mae'])
    return model

# %%
def build_multioutput_model(input_shape, n_features, output_steps, hidden=16):
    """
    This model predicts both Y and X features
    """
    inputs = Input(shape=input_shape)

    # LSTM process
    lstm_out = LSTM(hidden, activation='relu', return_sequences=False)(inputs)

    # Output for target
    y_output = Dense(output_steps, name='y_output')(lstm_out)

    # Output for features
    x_output_flat = Dense(output_steps * n_features, name='x_output')(lstm_out)
    x_output = tf.keras.layers.Reshape((output_steps, n_features), name='x_reshape')(x_output_flat)
    
    model = Model(inputs=inputs, outputs=[y_output, x_output])

    model.compile(
        optimizer=Adam(learning_rate=0.01),
        loss={'y_output': 'mse', 'x_output': 'mse'},
        loss_weights={'y_output': 1.0, 'x_output': 0.5}, # More weights for y_output
        metrics={'y_output': 'mae', 'x_output': 'mae'}
    )
    return model

# %% [markdown]
# ### LOCO
# Leave One Country Out

# %%
class LOCOForecaster:
    def __init__(self, model_func, input_steps=N_STEPS_IN, output_steps=N_STEPS_OUT):
        self.model_func = model_func
        self.input_steps = input_steps
        self.output_steps = output_steps
        self.model = None
        self.X_scaler = StandardScaler()
        self.y_scaler = StandardScaler()
        self.is_trained = False
        self.n_features = None

    def create_sequences(self, X, y):
        if len(X) < self.input_steps +self.output_steps:
            return np.array([]), np.array([])
        
        X_seq = []
        y_seq = []

        for i in range(len(X) - self.input_steps - self.output_steps + 1):
            X_seq.append(X[i:i + self.input_steps])
            y_seq.append(y[i + self.input_steps:i + self.input_steps + self.output_steps])
        
        X_seq = np.array(X_seq)
        y_seq = np.array(y_seq)

        # Check shapes
        if len(X_seq) > 0 and len(X_seq.shape) == 2:
            X_seq = X_seq.reshape(len(X_seq), self.input_steps, -1)

        if len(y_seq) > 0 and len(y_seq.shape) == 1:
            y_seq = y_seq.reshape(len(y_seq), self.output_steps)
        
        return X_seq, y_seq
    
    def train_model(self, X_train_pct, y_train_pct):
        self.n_features = X_train_pct.shape[1]

        # Scaling
        X_train_scaled = self.X_scaler.fit_transform(X_train_pct)
        y_train_scaled = self.y_scaler.fit_transform(y_train_pct.reshape(-1, 1)).ravel()
        
        # Seq
        X_train_seq, y_train_seq = self.create_sequences(X_train_scaled, y_train_scaled)
        
        if len(X_train_seq) == 0:
            print(f"Not enough data to create sequences")
            return
        
        print(f"Training sequences: {len(X_train_seq)}")

        # Model build
        input_shape = (self.input_steps, self.n_features)
        self.model = self.model_func(input_shape, self.output_steps)

        # Earlystopping
        callbacks = [EarlyStopping(monitor='loss', patience=20, restore_best_weights=True)]        

        # Batch size
        batch_size = min(16, len(X_train_seq))

        self.model.fit(
            X_train_seq, y_train_seq,
            epochs=100,
            batch_size=batch_size,
            callbacks=callbacks,
            verbose=0
        )

        self.is_trained = True

    def calculate_metrics(self, predictions, actuals, interation_num):
        
        if len(predictions) == 0 or len(actuals) == 0:
            return {'iteration': interation_num, 'rmse': np.nan, 'mase': np.nan}
        
        rmse_val = rmse(predictions, actuals)
        mase_val = mase(actuals, predictions)
        return {'iteration': interation_num, 'rmse': rmse_val, 'mase': mase_val}

    def non_recursive_forecast(self, X_train_pct, y_train_pct, X_test_pct, y_test_pct, y_train_original=None, y_test_original=None):
        if not self.is_trained:
            print("Model not trained")
            return None
        
        # Scaling the percentage change data
        X_train_scaled = self.X_scaler.transform(X_train_pct)
        X_test_scaled = self.X_scaler.transform(X_test_pct)
        
        predictions_pct = []
        actuals_pct = []
        predictions_actual = []
        actuals_actual = []
        iterations = []
        metrics_list = []

        # Iteration
        for iteration in range(3):
            if iteration == 0:
                X_window = X_train_scaled[-5:]
                start_idx = 0
                print(f"    Iter {iteration}: Using last 5 train values")
            elif iteration == 1:
                X_window = np.vstack([X_train_scaled[-2:], X_test_scaled[0:3]])
                start_idx = 3
                print(f"    Iter {iteration}: Using last 2 train + test[0:3]")
            elif iteration == 2:
                X_window = X_test_scaled[1:6]
                start_idx = 6
                print(f"    Iter {iteration}: Using test[1:6]")

            X_input = X_window.reshape(1, self.input_steps, -1)

            # Predict -> returns scaled values
            y_pred_scaled = self.model.predict(X_input, verbose=0)
            # ED-LSTM
            if len(y_pred_scaled.shape) == 3:
                y_pred_scaled = y_pred_scaled.reshape(-1)

            # y_pred_scaled is 1D
            y_pred_scaled = y_pred_scaled.flatten()

            # Inverse back to pct_change
            y_pred_pct = self.y_scaler.inverse_transform(y_pred_scaled.reshape(-1, 1)).ravel()

            # Actual values
            end_idx = min(start_idx + self.output_steps, len(y_test_pct))
            y_actual_pct = y_test_pct[start_idx:end_idx]

            # Convert back to actual values from pct_change
            if y_test_original is not None and y_train_original is not None:
                if iteration == 0:
                    # Use last training value
                    last_known_value = y_train_original[-1]
                else:
                    # Use last actual value from test
                    last_known_value = y_test_original[start_idx - 1]

                # Convert preds to actual values
                y_pred_actual = denormalise_pct_change(y_pred_pct[:len(y_actual_pct)], last_known_value)
                y_actual_actual = y_test_original[start_idx:end_idx]

                if len(y_actual_actual) == len(y_pred_actual):
                    predictions_actual.extend(y_pred_actual)
                    actuals_actual.extend(y_actual_actual)

                    # Metrics
                    metrics = self.calculate_metrics(y_pred_actual, y_actual_actual, iteration)
                else:
                    metrics = self.calculate_metrics(y_pred_pct[:len(y_actual_pct)], y_actual_pct, iteration)
            else:
                metrics = self.calculate_metrics(y_pred_pct[:len(y_actual_pct)], y_actual_pct, iteration)
            
            predictions_pct.extend(y_pred_pct)
            actuals_pct.extend(y_actual_pct)
            iterations.extend([iteration] * len(y_pred_pct))
            metrics_list.append(metrics)
            print(f"    RMSE: {metrics['rmse']:.4f}, MASE: {metrics['mase']:.4f}")
        
        results = {
            'predictions_pct': np.array(predictions_pct),
            'actuals_pct': np.array(actuals_pct),
            'iterations': np.array(iterations),
            'metrics': pd.DataFrame(metrics_list)
        }

        if len(predictions_actual) > 0:
            results['predictions_actual'] = np.array(predictions_actual)
            results['actuals_actual'] = np.array(actuals_actual)
        
        return results


    def recursive_forecast(self, X_train, y_train, X_test, y_test, y_train_original=None, y_test_original=None):
        if not self.is_trained:
            print(f"Model not trained")
            return None
        
        # Scale data
        X_train_scaled = self.X_scaler.transform(X_train)
        X_test_scaled = self.X_scaler.transform(X_test)
        
        predictions_pct = []
        actuals_pct = []
        predictions_actual = []
        actuals_actual = []
        iterations = []
        metrics_list = []

        # Store preds
        all_pred_windows = []

        for iteration in range(3):
            if iteration == 0:
                X_window = X_train_scaled[-5:]
                start_idx = 0
                print(f"    Iter {iteration}: Using last 5 training values")
            elif iteration == 1:
                if len(all_pred_windows) >= 3:
                    pred_window = np.array(all_pred_windows[0:3])
                    X_window = np.vstack([X_train_scaled[-2:], pred_window])
                    start_idx = 3
                    print(f"    Iter {iteration}: Using last 2 training + pred[0:3]")
                else:
                    print(f"    ERROR: Not enough predictions from previous iteration")
                    break
            elif iteration == 2:
                if len(all_pred_windows) >= 6:
                    X_window = np.array(all_pred_windows[1:6])
                    start_idx = 6
                    print(f"    Iter {iteration}: Using pred[1:6]")
                else:
                    print(f"    ERROR: Not enough preds for window (have {len(all_pred_windows)}, need 6)")
                    break
            
            X_input = X_window.reshape(1, self.input_steps, -1)

            # Predict
            y_pred_scaled = self.model.predict(X_input, verbose=0)
            # ED-LSTM
            if len(y_pred_scaled.shape) == 3:
                y_pred_scaled = y_pred_scaled.reshape(-1)

            # Ensure y_pred_scaled is 1D
            y_pred_scaled = y_pred_scaled.flatten()

            # Store preds and synthetic vectors with pred as first feature
            for i in range(self.output_steps):
                pred_features = np.zeros(self.n_features)

                pred_value = float(y_pred_scaled[i]) if np.isscalar(y_pred_scaled[i]) else float(y_pred_scaled[i].item())
                pred_features[0] = pred_value

                test_position = start_idx + i
                if test_position < len(X_test_scaled):
                    # Copy other features from test data
                    pred_features[1:] = X_test_scaled[test_position, 1:]
                else:
                    # Use last known features
                    pred_features[1:] = X_test_scaled[-1, 1:]

                all_pred_windows.append(pred_features)
            
            # Inverse transform to pct change
            y_pred_pct = self.y_scaler.inverse_transform(y_pred_scaled.reshape(-1, 1)).ravel()
            
            # Actual values for this iteration
            end_idx = min(start_idx + self.output_steps, len(y_test))
            y_actual_pct = y_test[start_idx:end_idx]
            
            # Convert back to actual values
            if y_test_original is not None and y_train_original is not None:
                if iteration == 0:
                    last_known_value = y_train_original[-1]
                else:
                    last_known_value = predictions_actual[-1] if len(predictions_actual) > 0 else y_train_original[-1]
                
                # Convert preds back to actual values
                y_pred_actual = denormalise_pct_change(y_pred_pct[:len(y_actual_pct)], last_known_value)
                y_actual_actual = y_test_original[start_idx:end_idx]
                
                if len(y_actual_actual) == len(y_pred_actual):
                    predictions_actual.extend(y_pred_actual)
                    actuals_actual.extend(y_actual_actual)
                    
                    # Metrics
                    metrics = self.calculate_metrics(y_pred_actual, y_actual_actual, iteration)
                else:
                    metrics = self.calculate_metrics(y_pred_pct[:len(y_actual_pct)], y_actual_pct, iteration)
            else:
                metrics = self.calculate_metrics(y_pred_pct[:len(y_actual_pct)], y_actual_pct, iteration)
            
            predictions_pct.extend(y_pred_pct)
            actuals_pct.extend(y_actual_pct)
            iterations.extend([iteration] * len(y_pred_pct))
            metrics_list.append(metrics)
            
            print(f"    RMSE: {metrics['rmse']:.4f}, MASE: {metrics['mase']:.4f}")
        
        results = {
            'predictions_pct': np.array(predictions_pct),
            'actuals_pct': np.array(actuals_pct),
            'iterations': np.array(iterations),
            'metrics': pd.DataFrame(metrics_list)
        }
        
        if len(predictions_actual) > 0:
            results['predictions_actual'] = np.array(predictions_actual)
            results['actuals_actual'] = np.array(actuals_actual)
        
        return results

# %%
class LOCOComparison:    
    def __init__(self, countries, features, target):
        self.countries = countries
        self.features = features
        self.target = target
    
    def run_comparison(self, data, test_country, model_func=build_lstm):
        print(f"Leave-One-Country-Out Comparison for: {test_country}")
        
        # Apply percentage change features
        data = pct_change_features(data)
        
        # Split countries
        train_countries = [c for c in self.countries if c != test_country]
        
        # Prepare training data from all other countries
        X_train_list = []
        y_train_list = []
        y_train_original_list = []
        
        for country in train_countries:
            country_data = data[data['country'] == country].sort_values('year')
            
            country_data, feature_cols, target_col = prepare_features(country_data, self.features, self.target, use_lags=True)
            
            original_target_col = f'{self.target}_original'
            
            valid_cols = feature_cols + [target_col]
            if original_target_col in country_data.columns:
                valid_cols.append(original_target_col)
            
            valid_data = country_data[valid_cols].dropna()
            
            if len(valid_data) > 0:
                # X and y are in percentage form
                X = valid_data[feature_cols].values
                y = valid_data[target_col].values
                y_original = valid_data[original_target_col].values if original_target_col in valid_data.columns else None
                
                # Use all data from other countries for training
                X_train_list.append(X)
                y_train_list.append(y)
                
                if y_original is not None:
                    y_train_original_list.append(y_original)
        
        # Combine training data (in pct)
        X_train_all_pct = np.vstack(X_train_list) if X_train_list else np.array([])
        y_train_all_pct = np.hstack(y_train_list) if y_train_list else np.array([])
        y_train_original_all = np.hstack(y_train_original_list) if y_train_original_list else None
        
        if len(X_train_all_pct) == 0:
            print("No training data available")
            return None
        
        print(f"Total training samples from other countries: {len(X_train_all_pct)}")
        
        # Test country data
        test_data = data[data['country'] == test_country].sort_values('year')
        test_data, feature_cols, target_col = prepare_features(test_data, self.features, self.target, use_lags=True)
        
        original_target_col = f'{self.target}_original'
        test_valid_cols = feature_cols + [target_col]
        if original_target_col in test_data.columns:
            test_valid_cols.append(original_target_col)
        
        test_valid = test_data[test_valid_cols].dropna()
        
        if len(test_valid) == 0:
            print(f"No valid data for test country {test_country}")
            return None
        
        # Split country data
        n_test_country_samples = len(test_valid)
        n_test = TEST_SAMPLES
        n_train = n_test_country_samples - n_test
        
        if n_train < N_STEPS_IN:
            print(f"Not enough training data for {test_country}")
            return None
        
        # Features and targets (pct)
        X_test_country_pct = test_valid[feature_cols].values
        y_test_country_pct = test_valid[target_col].values
        y_test_country_original = test_valid[original_target_col].values if original_target_col in test_valid.columns else None
        
        # Split into train/test for the test country
        X_train_from_test_pct = X_test_country_pct[:n_train]
        y_train_from_test_pct = y_test_country_pct[:n_train]
        y_train_from_test_original = y_test_country_original[:n_train] if y_test_country_original is not None else None
        
        X_test_pct = X_test_country_pct[n_train:n_train + n_test]
        y_test_pct = y_test_country_pct[n_train:n_train + n_test]
        y_test_original = y_test_country_original[n_train:n_train + n_test] if y_test_country_original is not None else None
        
        print(f"Test country train samples: {len(X_train_from_test_pct)}")
        print(f"Test country test samples: {len(X_test_pct)}")
        
        forecaster = LOCOForecaster(model_func)
        
        # Train model on all other countries' data
        forecaster.train_model(X_train_all_pct, y_train_all_pct)
        
        # Run both experiments
        results = {}
        
        # Non-recursive forecasting
        non_recursive_results = forecaster.non_recursive_forecast(
            X_train_from_test_pct, y_train_from_test_pct,
            X_test_pct, y_test_pct,
            y_train_from_test_original, y_test_original
        )
        if non_recursive_results is not None:
            results['non_recursive'] = non_recursive_results
        
        # Recursive forecasting
        recursive_results = forecaster.recursive_forecast(
            X_train_from_test_pct, y_train_from_test_pct,
            X_test_pct, y_test_pct,
            y_train_from_test_original, y_test_original
        )
        if recursive_results is not None:
            results['recursive'] = recursive_results
        
        self.print_summary(results, test_country)
        
        return results
    
    def print_summary(self, results, country):
        print(f"\nSummary for {country}")
        
        for strategy in ['non_recursive', 'recursive']:
            if strategy in results:
                res = results[strategy]
                
                if 'predictions_actual' in res and len(res['predictions_actual']) > 0:
                    preds = res['predictions_actual']
                    acts = res['actuals_actual']
                    data_type = "(actual values)"
                else:
                    preds = res['predictions_pct']
                    acts = res['actuals_pct']
                    data_type = "(% change)"
                
                if len(preds) > 0:
                    overall_rmse = rmse(preds, acts)
                    overall_mase = mase(acts, preds)
                    
                    strategy_name = "Non-Recursive" if strategy == 'non_recursive' else "Recursive"
                    print(f"\n{strategy_name} {data_type}:")
                    print(f"  Overall RMSE: {overall_rmse:.4f}")
                    print(f"  Overall MASE: {overall_mase:.4f}")
                    print(f"  Predictions made: {len(preds)}")

# %% [markdown]
# ### Single Country

# %%
class SingleCountryModel:
    def __init__(self, features, target):
        self.features = features
        self.target = target

    def run_single_country(self, data, country, model_func=build_lstm):
        print(f"\nSingle Country Model for {country}")

        data = pct_change_features(data)

        country_data = data[data['country'] == country].sort_values('year')

        country_data, feature_cols, target_col = prepare_features(country_data, self.features, self.target, use_lags=True)

        original_target_col = f'{self.target}_original'

        valid_cols = feature_cols + [target_col]
        if original_target_col in country_data.columns:
            valid_cols.append(original_target_col)

        valid_data = country_data[valid_cols].dropna()

        if len(valid_data) == 0:
            print(f"No valid data for {country}")
            return None
        
        # Split
        n_samples = len(valid_data)
        n_test = TEST_SAMPLES
        n_train = n_samples - n_test

        if n_train < N_STEPS_IN + N_STEPS_OUT:
            print(f"Not enough training data for {country}")
            return None

        X_pct = valid_data[feature_cols].values
        y_pct = valid_data[target_col].values
        y_original = valid_data[original_target_col].values if original_target_col in valid_data.columns else None
        
        X_train_pct = X_pct[:n_train]
        y_train_pct = y_pct[:n_train]
        y_train_original = y_original[:n_train] if y_original is not None else None
        
        X_test_pct = X_pct[n_train:n_train + n_test]
        y_test_pct = y_pct[n_train:n_train + n_test]
        y_test_original = y_original[n_train:n_train + n_test] if y_original is not None else None
        
        print(f"Training samples: {len(X_train_pct)}")
        print(f"Test samples: {len(X_test_pct)}")

        forecaster = LOCOForecaster(model_func)
        
        forecaster.train_model(X_train_pct, y_train_pct)
        
        results = {}
        
        # Non-recursive forecasting
        non_recursive_results = forecaster.non_recursive_forecast(
            X_train_pct, y_train_pct,
            X_test_pct, y_test_pct,
            y_train_original, y_test_original
        )
        if non_recursive_results is not None:
            results['non_recursive'] = non_recursive_results
        
        # Recursive forecasting
        recursive_results = forecaster.recursive_forecast(
            X_train_pct, y_train_pct,
            X_test_pct, y_test_pct,
            y_train_original, y_test_original
        )
        if recursive_results is not None:
            results['recursive'] = recursive_results
        
        # Print summary
        self.print_summary(results, country)
        
        return results
    
    def print_summary(self, results, country):
        print(f"\nSingle Country Summary for {country}")

        for strategy in ['non_recursive', 'recursive']:
            if strategy in results:
                res = results[strategy]

                if 'predictions_actual' in res and len(res['predictions_actual']) > 0:
                    preds = res['predictions_actual']
                    acts = res['actuals_actual']
                    data_type = "(actual values)"
                else:
                    preds = res['predictions_pct']
                    acts = res['actuals_pct']
                    data_type = "(% change)"
                
                if len(preds) > 0:
                    overall_rmse = rmse(preds, acts)
                    overall_mase = mase(acts, preds)
                    
                    strategy_name = "Non-Recursive" if strategy == 'non_recursive' else "Recursive"
                    print(f"\n{strategy_name} {data_type}:")
                    print(f"  Overall RMSE: {overall_rmse:.4f}")
                    print(f"  Overall MASE: {overall_mase:.4f}")
                    print(f"  Predictions made: {len(preds)}")

# %% [markdown]
# ### Visualisation

# %%
def plot_model_comparison(results, country, target, save_dir='data_export', use_actual_values=True):
    os.makedirs(os.path.join(save_dir, '04_plots'), exist_ok=True)
    
    fig, axes = plt.subplots(2, 4, figsize=(20, 10))
    fig.suptitle(f'{country} - {target}: LOCO vs Single Country Model Comparison', fontsize=16, y=1)
    
    model_types = ['loco', 'single']
    model_labels = ['Leave-One-Country-Out', 'Single Country']
    strategies = ['non_recursive', 'recursive']
    
    for model_idx, (model_type, model_label) in enumerate(zip(model_types, model_labels)):
        if model_type not in results:
            continue
        
        for strat_idx, strategy in enumerate(strategies):
            if strategy not in results[model_type]:
                continue

            strategy_results = results[model_type][strategy]

            if use_actual_values and 'predictions_actual' in strategy_results and len(strategy_results['predictions_actual']) > 0:
                predictions = strategy_results['predictions_actual']
                actuals = strategy_results['actuals_actual']
                value_label = f'{target} (Actual Values)'
            else:
                predictions = strategy_results['predictions_pct']
                actuals = strategy_results['actuals_pct']
                value_label = f'{target} (% Change)'
        
            # Plot predictions vs actuals
            ax1 = axes[model_idx, strat_idx * 2]
            ax1.plot(actuals, label='Actual', alpha=0.8, linewidth=2, color='blue')
            ax1.plot(predictions, label='Predicted', alpha=0.8, linewidth=2, color='orange')
            
            strategy_name = 'Non-Recursive' if strategy == 'non_recursive' else 'Recursive'
            ax1.set_title(f'{model_label} - {strategy_name}')
            ax1.set_xlabel('Time Step')
            ax1.set_ylabel(value_label)
            ax1.legend(loc='upper left')
            
            if len(predictions) >= 3:
                ax1.axvline(x=2.5, color='gray', linestyle=':', alpha=0.3)
            if len(predictions) >= 6:
                ax1.axvline(x=5.5, color='gray', linestyle=':', alpha=0.3)
            
            # Calculate residuals
            residuals = predictions - actuals
            
            # Plot residuals
            ax2 = axes[model_idx, strat_idx * 2 + 1]
            colors = ['red' if r > 0 else 'blue' for r in residuals]
            ax2.bar(range(len(residuals)), residuals, alpha=0.7, color=colors)
            ax2.axhline(y=0, color='black', linestyle='--', alpha=0.5)
            ax2.set_title(f'Residuals - {strategy_name}')
            ax2.set_xlabel('Time Step')
            ax2.set_ylabel('Prediction Error')
            
            # Add RMSE per iteration as bar chart
            metrics_df = strategy_results['metrics']
            if not metrics_df.empty:
                # Create inset axes for RMSE bars
                inset_ax = ax2.inset_axes([0.6, 0.6, 0.35, 0.35])
                inset_ax.bar(metrics_df['iteration'], metrics_df['rmse'], color='coral', alpha=0.7)
                inset_ax.set_xlabel('Iter', fontsize=8)
                inset_ax.set_ylabel('RMSE', fontsize=8)
                inset_ax.tick_params(labelsize=6)
            
            # Add overall metrics as text
            if len(predictions) > 0:
                overall_rmse = rmse(predictions, actuals)
                overall_mase = mase(actuals, predictions)
                
                metrics_text = f'RMSE: {overall_rmse:.4f}\nMASE: {overall_mase:.4f}'
                ax1.text(0.02, 0.98, metrics_text, transform=ax1.transAxes, va='top', ha='left',
                        bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.7),
                        fontsize=9)
    
    plt.tight_layout()
    
    # Save plot
    plot_path = os.path.join(save_dir, '04_plots', f'{country}_{target}_model_comparison.png')
    plt.savefig(plot_path, dpi=150, bbox_inches='tight')
    
    return fig

# %%
def plot_comparison_summary(summary_df, target, save_dir='data_export'):
    os.makedirs(os.path.join(save_dir, '04_plots'), exist_ok=True)
    
    fig, axes = plt.subplots(1, 2, figsize=(15, 6))
    fig.suptitle(f'Model Comparison Summary - Target: {target}', fontsize=14)
    
    summary_pivot = summary_df.pivot_table(
        index=['country', 'strategy'],
        columns='model_type',
        values='rmse',
        aggfunc='mean'
    ).reset_index()
    
    # Plot 1: RMSE comparison by country and strategy
    ax1 = axes[0]
    
    countries = summary_df['country'].unique()
    strategies = ['non_recursive', 'recursive']
    
    x = np.arange(len(countries))
    width = 0.3
    
    for i, strategy in enumerate(strategies):
        strategy_data = summary_df[summary_df['strategy'] == strategy]
        
        loco_rmse = []
        single_rmse = []
        
        for country in countries:
            loco_val = strategy_data[(strategy_data['country'] == country) & 
                                   (strategy_data['model_type'] == 'loco')]['rmse'].values
            single_val = strategy_data[(strategy_data['country'] == country) & 
                                     (strategy_data['model_type'] == 'single')]['rmse'].values
            
            loco_rmse.append(loco_val[0] if len(loco_val) > 0 else 0)
            single_rmse.append(single_val[0] if len(single_val) > 0 else 0)
        
        offset = width * (i - 0.5)
        
        bars1 = ax1.bar(x + offset - width/2, loco_rmse, width/2, 
                        label=f'LOCO {strategy.replace("_", "-")}',
                        alpha=0.8, color='blue' if i == 0 else 'darkblue')
        bars2 = ax1.bar(x + offset + width/2, single_rmse, width/2,
                        label=f'Single {strategy.replace("_", "-")}',
                        alpha=0.8, color='orange' if i == 0 else 'darkorange')
    
    ax1.set_xlabel('Country')
    ax1.set_ylabel('RMSE')
    ax1.set_title('RMSE Comparison by Country and Strategy')
    ax1.set_xticks(x)
    ax1.set_xticklabels(countries, rotation=45, ha='right')
    ax1.legend(loc='upper left', fontsize=9)
    
    # Plot 2: Percentage improvement of LOCO over Single Country
    ax2 = axes[1]
    
    improvement_data = []
    
    for country in countries:
        for strategy in strategies:
            loco_data = summary_df[(summary_df['country'] == country) & 
                                 (summary_df['strategy'] == strategy) & 
                                 (summary_df['model_type'] == 'loco')]
            single_data = summary_df[(summary_df['country'] == country) & 
                                    (summary_df['strategy'] == strategy) & 
                                    (summary_df['model_type'] == 'single')]
            
            if not loco_data.empty and not single_data.empty:
                loco_rmse = loco_data['rmse'].values[0]
                single_rmse = single_data['rmse'].values[0]
                
                # Percentage improvement (positive means LOCO is better)
                improvement = ((single_rmse - loco_rmse) / single_rmse) * 100
                
                improvement_data.append({
                    'country': country,
                    'strategy': strategy.replace('_', '-'),
                    'improvement': improvement
                })
    
    if improvement_data:
        improvement_df = pd.DataFrame(improvement_data)
        
        # Grouped bar chart
        improvement_pivot = improvement_df.pivot(
            index='country',
            columns='strategy',
            values='improvement'
        )
        
        improvement_pivot.plot(kind='bar', ax=ax2, width=0.7, alpha=0.8,
                               color=['green', 'darkgreen'])
        
        ax2.axhline(y=0, color='black', linestyle='-', linewidth=0.5)
        ax2.set_xlabel('Country')
        ax2.set_ylabel('Improvement (%)')
        ax2.set_title('LOCO Performance vs Single Country Model\n(Positive = LOCO Better)')
        ax2.legend(title='Strategy', loc='upper right')
        ax2.set_xticklabels(ax2.get_xticklabels(), rotation=45, ha='right')
        
        for container in ax2.containers:
            ax2.bar_label(container, fmt='%.1f%%', padding=3, fontsize=8)
    
    plt.tight_layout()
    
    # Save plot
    plot_path = os.path.join(save_dir, '04_plots', f'{target}_comparison_summary.png')
    plt.savefig(plot_path, dpi=150, bbox_inches='tight')
    
    return fig

# %% [markdown]
# ### Save Comparison

# %%
def run_developed_comparison(countries_to_test=None, target='co2', model_func=build_lstm, save_dir='data_export/04_results'):
    os.makedirs(save_dir, exist_ok=True)
    
    print("\nLOCO vs SINGLE DEVELOPED COUNTRY MODELS")
    print(f"Target: {target}")
    print(f"Model: {model_func.__name__}")
    print(f"Test size: {TEST_SAMPLES} samples")
    
    data = load_data()
    
    if countries_to_test is None:
        countries_to_test = DEVELOPED_COUNTRIES
    
    loco_comparison = LOCOComparison(DEVELOPED_COUNTRIES, FEATURES, target)
    single_country_model = SingleCountryModel(FEATURES, target)
    
    all_results = {}
    comparison_summary = []
    
    for test_country in countries_to_test:
        print(f"TESTING COUNTRY: {test_country}")
        
        country_results = {}
        
        # LOCO model
        print("\nLEAVE-ONE-COUNTRY-OUT MODEL")
        loco_results = loco_comparison.run_comparison(data, test_country, model_func)
        if loco_results is not None:
            country_results['loco'] = loco_results
        
        # Single Country model
        print("\nSINGLE COUNTRY MODEL")
        single_results = single_country_model.run_single_country(data, test_country, model_func)
        if single_results is not None:
            country_results['single'] = single_results
        
        all_results[test_country] = country_results
        
        # Comparison summary
        for model_type in ['loco', 'single']:
            if model_type in country_results:
                for strategy in ['non_recursive', 'recursive']:
                    if strategy in country_results[model_type]:
                        res = country_results[model_type][strategy]
                        
                        if 'predictions_actual' in res and len(res['predictions_actual']) > 0:
                            preds = res['predictions_actual']
                            acts = res['actuals_actual']
                            data_type = 'actual'
                        else:
                            preds = res['predictions_pct']
                            acts = res['actuals_pct']
                            data_type = 'pct'
                        
                        if len(preds) > 0:
                            comparison_summary.append({
                                'country': test_country,
                                'model_type': model_type,
                                'strategy': strategy,
                                'data_type': data_type,
                                'rmse': rmse(preds, acts),
                                'mase': mase(acts, preds),
                                'n_predictions': len(preds)
                            })
    
    # Final comparison
    if comparison_summary:
        summary_df = pd.DataFrame(comparison_summary)
        # Group by country for comparison
        for country in countries_to_test:
            country_df = summary_df[summary_df['country'] == country]
            if not country_df.empty:
                print(f"\n{country}:")
                
                # Compare LOCO vs Single for each strategy
                for strategy in ['non_recursive', 'recursive']:
                    strategy_df = country_df[country_df['strategy'] == strategy]
                    loco_row = strategy_df[strategy_df['model_type'] == 'loco']
                    single_row = strategy_df[strategy_df['model_type'] == 'single']
                    
                    if not loco_row.empty and not single_row.empty:
                        loco_rmse = loco_row.iloc[0]['rmse']
                        single_rmse = single_row.iloc[0]['rmse']
                        
                        print(f"\n  {strategy.upper()}:")
                        print(f"    LOCO RMSE:    {loco_rmse:.4f}")
                        print(f"    Single RMSE: {single_rmse:.4f}")
                        
                        if loco_rmse < single_rmse:
                            loco_better = ((single_rmse - loco_rmse) / single_rmse) * 100
                            print(f"    LOCO is {loco_better:.1f}% better")
                        else:
                            single_better = ((loco_rmse - single_rmse) / single_rmse) * 100
                            print(f"    Single Country is {single_better:.1f}% better")
        
        # Save summary
        summary_path = os.path.join(save_dir, f'comparison_summary_{target}.csv')
        summary_df.to_csv(summary_path, index=False)
    
    clear_memory()
    
    return all_results, summary_df if comparison_summary else None

# %%
def run_developing_comparison(countries_to_test=None, target='co2', model_func=build_lstm, save_dir='data_export/04_results'):
    os.makedirs(save_dir, exist_ok=True)
    
    print("\nLOCO vs SINGLE DEVELOPING COUNTRY MODELS")
    print(f"Target: {target}")
    print(f"Model: {model_func.__name__}")
    print(f"Test size: {TEST_SAMPLES} samples")
    
    data = load_data()
    
    if countries_to_test is None:
        countries_to_test = DEVELOPING_COUNTRIES
    
    loco_comparison = LOCOComparison(DEVELOPING_COUNTRIES, FEATURES, target)
    single_country_model = SingleCountryModel(FEATURES, target)
    
    all_results = {}
    comparison_summary = []
    
    for test_country in countries_to_test:
        print(f"TESTING COUNTRY: {test_country}")
        
        country_results = {}
        
        # LOCO model
        print("\nLEAVE-ONE-COUNTRY-OUT MODEL")
        loco_results = loco_comparison.run_comparison(data, test_country, model_func)
        if loco_results is not None:
            country_results['loco'] = loco_results
        
        # Single Country model
        print("\nSINGLE COUNTRY MODEL")
        single_results = single_country_model.run_single_country(data, test_country, model_func)
        if single_results is not None:
            country_results['single'] = single_results
        
        all_results[test_country] = country_results
        
        # Comparison summary
        for model_type in ['loco', 'single']:
            if model_type in country_results:
                for strategy in ['non_recursive', 'recursive']:
                    if strategy in country_results[model_type]:
                        res = country_results[model_type][strategy]
                        
                        if 'predictions_actual' in res and len(res['predictions_actual']) > 0:
                            preds = res['predictions_actual']
                            acts = res['actuals_actual']
                            data_type = 'actual'
                        else:
                            preds = res['predictions_pct']
                            acts = res['actuals_pct']
                            data_type = 'pct'
                        
                        if len(preds) > 0:
                            comparison_summary.append({
                                'country': test_country,
                                'model_type': model_type,
                                'strategy': strategy,
                                'data_type': data_type,
                                'rmse': rmse(preds, acts),
                                'mase': mase(acts, preds),
                                'n_predictions': len(preds)
                            })
    
    # Final comparison
    if comparison_summary:
        summary_df = pd.DataFrame(comparison_summary)
        # Group by country for comparison
        for country in countries_to_test:
            country_df = summary_df[summary_df['country'] == country]
            if not country_df.empty:
                print(f"\n{country}:")
                
                # Compare LOCO vs Single for each strategy
                for strategy in ['non_recursive', 'recursive']:
                    strategy_df = country_df[country_df['strategy'] == strategy]
                    loco_row = strategy_df[strategy_df['model_type'] == 'loco']
                    single_row = strategy_df[strategy_df['model_type'] == 'single']
                    
                    if not loco_row.empty and not single_row.empty:
                        loco_rmse = loco_row.iloc[0]['rmse']
                        single_rmse = single_row.iloc[0]['rmse']
                        
                        print(f"\n  {strategy.upper()}:")
                        print(f"    LOCO RMSE:    {loco_rmse:.4f}")
                        print(f"    Single RMSE: {single_rmse:.4f}")
                        
                        if loco_rmse < single_rmse:
                            loco_better = ((single_rmse - loco_rmse) / single_rmse) * 100
                            print(f"    LOCO is {loco_better:.1f}% better")
                        else:
                            single_better = ((loco_rmse - single_rmse) / single_rmse) * 100
                            print(f"    Single Country is {single_better:.1f}% better")
        
        # Save summary
        summary_path = os.path.join(save_dir, f'comparison_summary_{target}.csv')
        summary_df.to_csv(summary_path, index=False)
    
    clear_memory()
    
    return all_results, summary_df if comparison_summary else None

# %% [markdown]
# ### Running

# %%
def co2_developed_run():
    results, summary = run_developed_comparison(
            countries_to_test=DEVELOPED_COUNTRIES,
            target='co2',
            model_func=build_lstm,
            save_dir='data_export/04_results/developed'
        )

    for country in DEVELOPED_COUNTRIES:
        if country in results:
            print(f"\nPlot comparison for {country}")
            
            country_results = results[country]
            
            fig = plot_model_comparison(
                country_results, 
                country, 
                target='co2',
                save_dir='data_export/04_plots/developed',
                use_actual_values=True
            )
            plt.show()

    if summary is not None:
        
        fig_summary = plot_comparison_summary(
            summary,
            target='co2',
            save_dir='data_export/04_plots/developed'
        )
        plt.show()
        
        print("NUMERICAL SUMMARY")
        
        for country in DEVELOPED_COUNTRIES:
            country_data = summary[summary['country'] == country]
            
            if not country_data.empty:
                print(f"\n{country}:")
                
                for strategy in ['non_recursive', 'recursive']:
                    strategy_data = country_data[country_data['strategy'] == strategy]
                    
                    loco_rmse = strategy_data[strategy_data['model_type'] == 'loco']['rmse'].values
                    single_rmse = strategy_data[strategy_data['model_type'] == 'single']['rmse'].values
                    
                    if len(loco_rmse) > 0 and len(single_rmse) > 0:
                        improvement = ((single_rmse[0] - loco_rmse[0]) / single_rmse[0]) * 100
                        
                        print(f"  {strategy}:")
                        print(f"    LOCO RMSE:    {loco_rmse[0]:.4f}")
                        print(f"    Single RMSE: {single_rmse[0]:.4f}")
                        print(f"    Improvement: {improvement:.2f}%")

    return results, summary

# %%
def co2_developing_run():
    results, summary = run_developing_comparison(
            countries_to_test=DEVELOPING_COUNTRIES,
            target='co2',
            model_func=build_lstm,
            save_dir='data_export/04_results/developing'
        )

    for country in DEVELOPING_COUNTRIES:
        if country in results:
            print(f"\nPlot comparison for {country}")
            
            country_results = results[country]
            
            fig = plot_model_comparison(
                country_results, 
                country, 
                target='co2',
                save_dir='data_export/04_plots/developing',
                use_actual_values=True
            )
            plt.show()

    if summary is not None:
        
        fig_summary = plot_comparison_summary(
            summary,
            target='co2',
            save_dir='data_export/04_plots/developing'
        )
        plt.show()
        
        print("NUMERICAL SUMMARY")
        
        for country in DEVELOPING_COUNTRIES:
            country_data = summary[summary['country'] == country]
            
            if not country_data.empty:
                print(f"\n{country}:")
                
                for strategy in ['non_recursive', 'recursive']:
                    strategy_data = country_data[country_data['strategy'] == strategy]
                    
                    loco_rmse = strategy_data[strategy_data['model_type'] == 'loco']['rmse'].values
                    single_rmse = strategy_data[strategy_data['model_type'] == 'single']['rmse'].values
                    
                    if len(loco_rmse) > 0 and len(single_rmse) > 0:
                        improvement = ((single_rmse[0] - loco_rmse[0]) / single_rmse[0]) * 100
                        
                        print(f"  {strategy}:")
                        print(f"    LOCO RMSE:    {loco_rmse[0]:.4f}")
                        print(f"    Single RMSE: {single_rmse[0]:.4f}")
                        print(f"    Improvement: {improvement:.2f}%")

    return results, summary

# %%
def gdp_developed_run():
    results, summary = run_developed_comparison(
            countries_to_test=DEVELOPED_COUNTRIES,
            target='gdp',
            model_func=build_cnn,
            save_dir='data_export/04_results/developed'
        )

    for country in DEVELOPED_COUNTRIES:
        if country in results:
            print(f"\nPlot comparison for {country}")
            
            country_results = results[country]
            
            fig = plot_model_comparison(
                country_results, 
                country, 
                target='gdp',
                save_dir='data_export/04_plots/developed',
                use_actual_values=True
            )
            plt.show()

    if summary is not None:
        
        fig_summary = plot_comparison_summary(
            summary,
            target='gdp',
            save_dir='data_export/04_plots/developed'
        )
        plt.show()
        
        print("NUMERICAL SUMMARY")
        
        for country in DEVELOPED_COUNTRIES:
            country_data = summary[summary['country'] == country]
            
            if not country_data.empty:
                print(f"\n{country}:")
                
                for strategy in ['non_recursive', 'recursive']:
                    strategy_data = country_data[country_data['strategy'] == strategy]
                    
                    loco_rmse = strategy_data[strategy_data['model_type'] == 'loco']['rmse'].values
                    single_rmse = strategy_data[strategy_data['model_type'] == 'single']['rmse'].values
                    
                    if len(loco_rmse) > 0 and len(single_rmse) > 0:
                        improvement = ((single_rmse[0] - loco_rmse[0]) / single_rmse[0]) * 100
                        
                        print(f"  {strategy}:")
                        print(f"    LOCO RMSE:    {loco_rmse[0]:.4f}")
                        print(f"    Single RMSE: {single_rmse[0]:.4f}")
                        print(f"    Improvement: {improvement:.2f}%")

    return results, summary

# %%
def gdp_developing_run():
    results, summary = run_developing_comparison(
            countries_to_test=DEVELOPING_COUNTRIES,
            target='gdp',
            model_func=build_cnn,
            save_dir='data_export/04_results/developing'
        )

    for country in DEVELOPING_COUNTRIES:
        if country in results:
            print(f"\nPlot comparison for {country}")
            
            country_results = results[country]
            
            fig = plot_model_comparison(
                country_results, 
                country, 
                target='gdp',
                save_dir='data_export/04_plots/developing',
                use_actual_values=True
            )
            plt.show()

    if summary is not None:
        
        fig_summary = plot_comparison_summary(
            summary,
            target='gdp',
            save_dir='data_export/04_plots/developing'
        )
        plt.show()
        
        print("NUMERICAL SUMMARY")
        
        for country in DEVELOPING_COUNTRIES:
            country_data = summary[summary['country'] == country]
            
            if not country_data.empty:
                print(f"\n{country}:")
                
                for strategy in ['non_recursive', 'recursive']:
                    strategy_data = country_data[country_data['strategy'] == strategy]
                    
                    loco_rmse = strategy_data[strategy_data['model_type'] == 'loco']['rmse'].values
                    single_rmse = strategy_data[strategy_data['model_type'] == 'single']['rmse'].values
                    
                    if len(loco_rmse) > 0 and len(single_rmse) > 0:
                        improvement = ((single_rmse[0] - loco_rmse[0]) / single_rmse[0]) * 100
                        
                        print(f"  {strategy}:")
                        print(f"    LOCO RMSE:    {loco_rmse[0]:.4f}")
                        print(f"    Single RMSE: {single_rmse[0]:.4f}")
                        print(f"    Improvement: {improvement:.2f}%")

    return results, summary

# %%
def energy_developed_run():
    results, summary = run_developed_comparison(
            countries_to_test=DEVELOPED_COUNTRIES,
            target='primary_energy_consumption',
            model_func=build_bilstm,
            save_dir='data_export/04_results/developed'
        )

    for country in DEVELOPED_COUNTRIES:
        if country in results:
            print(f"\nPlot comparison for {country}")
            
            country_results = results[country]
            
            fig = plot_model_comparison(
                country_results, 
                country, 
                target='primary_energy_consumption',
                save_dir='data_export/04_plots/developed',
                use_actual_values=True
            )
            plt.show()

    if summary is not None:
        
        fig_summary = plot_comparison_summary(
            summary,
            target='primary_energy_consumption',
            save_dir='data_export/04_plots/developed'
        )
        plt.show()
        
        print("NUMERICAL SUMMARY")
        
        for country in DEVELOPED_COUNTRIES:
            country_data = summary[summary['country'] == country]
            
            if not country_data.empty:
                print(f"\n{country}:")
                
                for strategy in ['non_recursive', 'recursive']:
                    strategy_data = country_data[country_data['strategy'] == strategy]
                    
                    loco_rmse = strategy_data[strategy_data['model_type'] == 'loco']['rmse'].values
                    single_rmse = strategy_data[strategy_data['model_type'] == 'single']['rmse'].values
                    
                    if len(loco_rmse) > 0 and len(single_rmse) > 0:
                        improvement = ((single_rmse[0] - loco_rmse[0]) / single_rmse[0]) * 100
                        
                        print(f"  {strategy}:")
                        print(f"    LOCO RMSE:    {loco_rmse[0]:.4f}")
                        print(f"    Single RMSE: {single_rmse[0]:.4f}")
                        print(f"    Improvement: {improvement:.2f}%")

    return results, summary

# %%
def energy_developing_run():
    results, summary = run_developing_comparison(
            countries_to_test=DEVELOPING_COUNTRIES,
            target='primary_energy_consumption',
            model_func=build_bilstm,
            save_dir='data_export/04_results/developing'
        )

    for country in DEVELOPING_COUNTRIES:
        if country in results:
            print(f"\nPlot comparison for {country}")
            
            country_results = results[country]
            
            fig = plot_model_comparison(
                country_results, 
                country, 
                target='primary_energy_consumption',
                save_dir='data_export/04_plots/developing',
                use_actual_values=True
            )
            plt.show()

    if summary is not None:
        
        fig_summary = plot_comparison_summary(
            summary,
            target='primary_energy_consumption',
            save_dir='data_export/04_plots/developing'
        )
        plt.show()
        
        print("NUMERICAL SUMMARY")
        
        for country in DEVELOPING_COUNTRIES:
            country_data = summary[summary['country'] == country]
            
            if not country_data.empty:
                print(f"\n{country}:")
                
                for strategy in ['non_recursive', 'recursive']:
                    strategy_data = country_data[country_data['strategy'] == strategy]
                    
                    loco_rmse = strategy_data[strategy_data['model_type'] == 'loco']['rmse'].values
                    single_rmse = strategy_data[strategy_data['model_type'] == 'single']['rmse'].values
                    
                    if len(loco_rmse) > 0 and len(single_rmse) > 0:
                        improvement = ((single_rmse[0] - loco_rmse[0]) / single_rmse[0]) * 100
                        
                        print(f"  {strategy}:")
                        print(f"    LOCO RMSE:    {loco_rmse[0]:.4f}")
                        print(f"    Single RMSE: {single_rmse[0]:.4f}")
                        print(f"    Improvement: {improvement:.2f}%")

    return results, summary

# %%
def create_final_summary(save_dir='data_export/04_results/final'):
    os.makedirs(save_dir, exist_ok=True)

    all_sum = []

    experiments = [
        {
            'target': 'co2',
            'model_func': build_lstm,
            'model_name': 'LSTM',
            'country_groups': [
                ('developed', DEVELOPED_COUNTRIES),
                ('developing', DEVELOPING_COUNTRIES)
            ]
        },
        {
            'target': 'co2',
            'model_func': build_bilstm,
            'model_name': 'Bi-LSTM',
            'country_groups': [
                ('developed', DEVELOPED_COUNTRIES),
                ('developing', DEVELOPING_COUNTRIES)
            ]
        },
        {
            'target': 'co2',
            'model_func': build_edlstm,
            'model_name': 'ED-LSTM',
            'country_groups': [
                ('developed', DEVELOPED_COUNTRIES),
                ('developing', DEVELOPING_COUNTRIES)
            ]
        },
        {
            'target': 'co2',
            'model_func': build_cnn,
            'model_name': 'CNN',
            'country_groups': [
                ('developed', DEVELOPED_COUNTRIES),
                ('developing', DEVELOPING_COUNTRIES)
            ]
        },
        {
            'target': 'gdp',
            'model_func': build_lstm,
            'model_name': 'LSTM',
            'country_groups': [
                ('developed', DEVELOPED_COUNTRIES),
                ('developing', DEVELOPING_COUNTRIES)
            ]
        },
        {
            'target': 'gdp',
            'model_func': build_bilstm,
            'model_name': 'Bi-LSTM',
            'country_groups': [
                ('developed', DEVELOPED_COUNTRIES),
                ('developing', DEVELOPING_COUNTRIES)
            ]
        },
        {
            'target': 'gdp',
            'model_func': build_edlstm,
            'model_name': 'ED-LSTM',
            'country_groups': [
                ('developed', DEVELOPED_COUNTRIES),
                ('developing', DEVELOPING_COUNTRIES)
            ]
        },
        {
            'target': 'gdp',
            'model_func': build_cnn,
            'model_name': 'CNN',
            'country_groups': [
                ('developed', DEVELOPED_COUNTRIES),
                ('developing', DEVELOPING_COUNTRIES)
            ]
        },
        {
            'target': 'primary_energy_consumption',
            'model_func': build_lstm,
            'model_name': 'LSTM',
            'country_groups': [
                ('developed', DEVELOPED_COUNTRIES),
                ('developing', DEVELOPING_COUNTRIES)
            ]
        },
        {
            'target': 'primary_energy_consumption',
            'model_func': build_bilstm,
            'model_name': 'Bi-LSTM',
            'country_groups': [
                ('developed', DEVELOPED_COUNTRIES),
                ('developing', DEVELOPING_COUNTRIES)
            ]
        },
        {
            'target': 'primary_energy_consumption',
            'model_func': build_edlstm,
            'model_name': 'ED-LSTM',
            'country_groups': [
                ('developed', DEVELOPED_COUNTRIES),
                ('developing', DEVELOPING_COUNTRIES)
            ]
        },
        {
            'target': 'primary_energy_consumption',
            'model_func': build_cnn,
            'model_name': 'CNN',
            'country_groups': [
                ('developed', DEVELOPED_COUNTRIES),
                ('developing', DEVELOPING_COUNTRIES)
            ]
        }
    ]

    for exp in experiments:
        target = exp['target']
        model_func = exp['model_func']
        model_name = exp['model_name']
        
        for group_name, countries in exp['country_groups']:
            print(f"\nRunning {target} - {model_name} - {group_name}")
            
            # Choose comparison function
            if group_name == 'developed':
                results, summary = run_developed_comparison(
                    countries_to_test=countries,
                    target=target,
                    model_func=model_func,
                    save_dir=f'{save_dir}/{group_name}'
                )
            else:
                results, summary = run_developing_comparison(
                    countries_to_test=countries,
                    target=target,
                    model_func=model_func,
                    save_dir=f'{save_dir}/{group_name}'
                )
            
            # Add data to summary
            if summary is not None and not summary.empty:
                summary = summary.copy()
                summary['target'] = target
                summary['model'] = model_name
                summary['country_group'] = group_name
                all_sum.append(summary)
            
            plot_dir = 'data_export/04_plots/final'
            os.makedirs(plot_dir, exist_ok=True)

            if results is not None:
                for country in countries:
                    if country in results:
                        fig = plot_model_comparison(results[country], country, target=target, save_dir=f'{plot_dir}/{group_name}', use_actual_values=True)
                        plt.close(fig)

                if summary is not None and not summary.empty:
                    fig_summary = plot_comparison_summary(summary, target=target, save_dir=f'{plot_dir}/{group_name}')
                    plt.close(fig_summary)
            
            clear_memory()
    
    # Combine all summaries
    if not all_sum:
        print("No summary data collected")
        return None
    
    combined_summary = pd.concat(all_sum, ignore_index=True)
    
    # Create final summary table
    final_summary_rows = []
    
    # Group by all relevant dim
    grouping_cols = ['target', 'model', 'country_group', 'strategy', 'model_type']
    
    for group_key, group_data in combined_summary.groupby(grouping_cols):
        target, model, country_group, strategy, model_type = group_key
        
        # Map model_type
        data_type = "Single Country" if model_type == 'single' else "All Country (LOCO)"
        
        # Calculate agg metrics
        rmse_values = group_data['rmse'].dropna()
        mase_values = group_data['mase'].dropna()
        
        if len(rmse_values) > 0:
            # Find countries with max and min RMSE
            max_rmse_idx = group_data['rmse'].idxmax()
            min_rmse_idx = group_data['rmse'].idxmin()
            max_rmse_country = group_data.loc[max_rmse_idx, 'country']
            min_rmse_country = group_data.loc[min_rmse_idx, 'country']
            
            final_summary_rows.append({
                'Data_Type': data_type,
                'Method': 'Autoregressive - 4 lags',
                'Strategy': strategy.replace('_', '-').title(),
                'Model': model,
                'Target': target.replace('_', ' ').title(),
                'Country_Group': country_group.title(),
                'Avg_RMSE': rmse_values.mean(),
                'Median_RMSE': rmse_values.median(),
                'Max_RMSE': rmse_values.max(),
                'Min_RMSE': rmse_values.min(),
                'Max_RMSE_Country': max_rmse_country,
                'Min_RMSE_Country': min_rmse_country,
                'Avg_MASE': mase_values.mean() if len(mase_values) > 0 else np.nan,
                'N_Countries': len(group_data)
            })
    
    # Create DataFrame
    final_summary_df = pd.DataFrame(final_summary_rows)
    
    # Sort by target, country group, model type
    final_summary_df = final_summary_df.sort_values([
        'Target', 'Country_Group', 'Model', 'Strategy', 'Data_Type'
    ]).reset_index(drop=True)
    
    # Save to CSV
    summary_path = os.path.join(save_dir, 'final_summary_table.csv')
    final_summary_df.to_csv(summary_path, index=False, float_format='%.4f')
    
    print(f"Total rows in summary: {len(final_summary_df)}")
    
    # Show a few sample rows
    display_cols = ['Data_Type', 'Strategy', 'Model', 'Target', 'Country_Group', 'Avg_RMSE', 'Avg_MASE']
    print(final_summary_df[display_cols].head(10).to_string(index=False))
    
    return final_summary_df

# %%
def generate_performance_comparison_table(final_summary_df, save_dir='data_export/04_results/final'):
    if final_summary_df is None:
        print("No summary data available for comparison")
        return None
    
    comparison_rows = []
    
    # Group by target, model, country_group, strategy to compare LOCO vs Single
    grouping_cols = ['Target', 'Model', 'Country_Group', 'Strategy']
    
    for group_key, group_data in final_summary_df.groupby(grouping_cols):
        target, model, country_group, strategy = group_key
        
        # Get LOCO and Single Country results
        loco_data = group_data[group_data['Data_Type'] == 'All Country (LOCO)']
        single_data = group_data[group_data['Data_Type'] == 'Single Country']
        
        if not loco_data.empty and not single_data.empty:
            loco_rmse = loco_data['Avg_RMSE'].iloc[0]
            single_rmse = single_data['Avg_RMSE'].iloc[0]
            
            # Calculate improvement percentage
            if single_rmse != 0:
                improvement_pct = ((single_rmse - loco_rmse) / single_rmse) * 100
            else:
                improvement_pct = 0
            
            better_method = "LOCO" if loco_rmse < single_rmse else "Single Country"
            
            comparison_rows.append({
                'Target': target,
                'Model': model,
                'Country_Group': country_group,
                'Strategy': strategy,
                'LOCO_Avg_RMSE': loco_rmse,
                'Single_Avg_RMSE': single_rmse,
                'Better_Method': better_method,
                'Improvement_Pct': abs(improvement_pct)
            })
    
    comparison_df = pd.DataFrame(comparison_rows)
    
    if not comparison_df.empty:
        # Save comparison table
        comparison_path = os.path.join(save_dir, 'performance_comparison_table.csv')
        comparison_df.to_csv(comparison_path, index=False, float_format='%.4f')
        
        better_counts = comparison_df['Better_Method'].value_counts()
        total_comparisons = len(comparison_df)
        
        for method, count in better_counts.items():
            pct = (count / total_comparisons) * 100
            print(f"{method}: {count}/{total_comparisons} ({pct:.1f}%)")
        
        # Show average improvement by method
        loco_wins = comparison_df[comparison_df['Better_Method'] == 'LOCO']
        single_wins = comparison_df[comparison_df['Better_Method'] == 'Single Country']
        
        if not loco_wins.empty:
            avg_loco_improvement = loco_wins['Improvement_Pct'].mean()
            print(f"\nAverage improvement when LOCO wins: {avg_loco_improvement:.2f}%")
        
        if not single_wins.empty:
            avg_single_improvement = single_wins['Improvement_Pct'].mean()
            print(f"Average improvement when Single Country wins: {avg_single_improvement:.2f}%")
    
    return comparison_df

# %%
final_summary = create_final_summary()
performance_comparison = generate_performance_comparison_table(final_summary)
# Out:
# Running co2 - LSTM - developed
#
# LOCO vs SINGLE DEVELOPED COUNTRY MODELS
# Target: co2
# Model: build_lstm
# Test size: 9 samples
# Data Shape: (1138, 992)
# TESTING COUNTRY: United States
#
# LEAVE-ONE-COUNTRY-OUT MODEL
# Leave-One-Country-Out Comparison for: United States
# Total training samples from other countries: 279
# Test country train samples: 26
# Test country test samples: 9
# Training sequences: 272
#     Iter 0: Using last 5 train values
#     RMSE: 1917.0948, MASE: 22.7166
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 998.2843, MASE: 2.7582
#     Iter 2: Using test[1:6]
#     RMSE: 142.6104, MASE: 1.0689
#     Iter 0: Using last 5 training values
#     RMSE: 1917.0948, MASE: 22.7166
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 3623.5583, MASE: 10.8083
#     Iter 2: Using pred[1:6]
#     RMSE: 4177.5850, MASE: 38.9495
#
# Summary for United States
#
# Non-Recursive (actual values):
#   Overall RMSE: 1250.6214
#   Overall MASE: 5.0634
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 3379.2328
#   Overall MASE: 16.8244
#   Predictions made: 9
#
# SINGLE COUNTRY MODEL
#
# Single Country Model for United States
# Training samples: 26
# Test samples: 9
# Training sequences: 19
#     Iter 0: Using last 5 train values
#     RMSE: 163.6766, MASE: 1.7824
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 269.0238, MASE: 0.6902
#     Iter 2: Using test[1:6]
#     RMSE: 249.2041, MASE: 2.3044
#     Iter 0: Using last 5 training values
#     RMSE: 163.6766, MASE: 1.7824
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 332.9313, MASE: 0.6615
#     Iter 2: Using pred[1:6]
#     RMSE: 327.6452, MASE: 3.0422
#
# Single Country Summary for United States
#
# Non-Recursive (actual values):
#   Overall RMSE: 231.8524
#   Overall MASE: 1.0878
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 285.7648
#   Overall MASE: 1.2093
#   Predictions made: 9
# TESTING COUNTRY: Japan
#
# LEAVE-ONE-COUNTRY-OUT MODEL
# Leave-One-Country-Out Comparison for: Japan
# Total training samples from other countries: 279
# Test country train samples: 26
# Test country test samples: 9
# Training sequences: 272
#     Iter 0: Using last 5 train values
#     RMSE: 62.0694, MASE: 3.3657
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 71.7182, MASE: 1.1821
#     Iter 2: Using test[1:6]
#     RMSE: 95.3160, MASE: 2.1727
#     Iter 0: Using last 5 training values
#     RMSE: 62.0694, MASE: 3.3657
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 134.3630, MASE: 2.4358
#     Iter 2: Using pred[1:6]
#     RMSE: 275.0904, MASE: 7.3109
#
# Summary for Japan
#
# Non-Recursive (actual values):
#   Overall RMSE: 77.6343
#   Overall MASE: 1.9219
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 180.3522
#   Overall MASE: 4.3436
#   Predictions made: 9
#
# SINGLE COUNTRY MODEL
#
# Single Country Model for Japan
# Training samples: 26
# Test samples: 9
# Training sequences: 19
#     Iter 0: Using last 5 train values
#     RMSE: 78.5834, MASE: 4.3834
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 93.3532, MASE: 1.8300
#     Iter 2: Using test[1:6]
#     RMSE: 397.4507, MASE: 8.3600
#     Iter 0: Using last 5 training values
#     RMSE: 78.5834, MASE: 4.3834
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 142.7973, MASE: 2.4540
#     Iter 2: Using pred[1:6]
#     RMSE: 375.5853, MASE: 7.8879
#
# Single Country Summary for Japan
#
# Non-Recursive (actual values):
#   Overall RMSE: 240.0397
#   Overall MASE: 4.5902
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 236.3830
#   Overall MASE: 4.7302
#   Predictions made: 9
# TESTING COUNTRY: Germany
#
# LEAVE-ONE-COUNTRY-OUT MODEL
# Leave-One-Country-Out Comparison for: Germany
# Total training samples from other countries: 279
# Test country train samples: 26
# Test country test samples: 9
# Training sequences: 272
#     Iter 0: Using last 5 train values
#     RMSE: 22.2300, MASE: 2.7358
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 26.5755, MASE: 0.4135
#     Iter 2: Using test[1:6]
#     RMSE: 27.2757, MASE: 0.6448
#     Iter 0: Using last 5 training values
#     RMSE: 22.2300, MASE: 2.7358
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 13.4745, MASE: 0.2071
#     Iter 2: Using pred[1:6]
#     RMSE: 27.4924, MASE: 0.6410
#
# Summary for Germany
#
# Non-Recursive (actual values):
#   Overall RMSE: 25.4584
#   Overall MASE: 0.7227
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 21.8447
#   Overall MASE: 0.6053
#   Predictions made: 9
#
# SINGLE COUNTRY MODEL
#
# Single Country Model for Germany
# Training samples: 26
# Test samples: 9
# Training sequences: 19
#     Iter 0: Using last 5 train values
#     RMSE: 13.1952, MASE: 1.4058
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 69.8536, MASE: 1.0915
#     Iter 2: Using test[1:6]
#     RMSE: 33.8631, MASE: 0.8021
#     Iter 0: Using last 5 training values
#     RMSE: 13.1952, MASE: 1.4058
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 72.5469, MASE: 1.1569
#     Iter 2: Using pred[1:6]
#     RMSE: 90.3207, MASE: 2.0769
#
# Single Country Summary for Germany
#
# Non-Recursive (actual values):
#   Overall RMSE: 45.4619
#   Overall MASE: 1.0596
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 67.3176
#   Overall MASE: 1.6252
#   Predictions made: 9
# TESTING COUNTRY: United Kingdom
#
# LEAVE-ONE-COUNTRY-OUT MODEL
# Leave-One-Country-Out Comparison for: United Kingdom
# Total training samples from other countries: 279
# Test country train samples: 26
# Test country test samples: 9
# Training sequences: 272
#     Iter 0: Using last 5 train values
#     RMSE: 91.5638, MASE: 4.9792
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 32.8727, MASE: 1.1080
#     Iter 2: Using test[1:6]
#     RMSE: 12.1781, MASE: 0.4963
#     Iter 0: Using last 5 training values
#     RMSE: 91.5638, MASE: 4.9792
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 144.0841, MASE: 5.3760
#     Iter 2: Using pred[1:6]
#     RMSE: 150.1896, MASE: 7.6108
#
# Summary for United Kingdom
#
# Non-Recursive (actual values):
#   Overall RMSE: 56.6064
#   Overall MASE: 2.1977
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 131.2772
#   Overall MASE: 6.6036
#   Predictions made: 9
#
# SINGLE COUNTRY MODEL
#
# Single Country Model for United Kingdom
# Training samples: 26
# Test samples: 9
# Training sequences: 19
#     Iter 0: Using last 5 train values
#     RMSE: 29.0275, MASE: 1.6008
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 35.3202, MASE: 1.2371
#     Iter 2: Using test[1:6]
#     RMSE: 13.1348, MASE: 0.6037
#     Iter 0: Using last 5 training values
#     RMSE: 29.0275, MASE: 1.6008
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 60.2778, MASE: 2.2020
#     Iter 2: Using pred[1:6]
#     RMSE: 80.8153, MASE: 4.0764
#
# Single Country Summary for United Kingdom
#
# Non-Recursive (actual values):
#   Overall RMSE: 27.4629
#   Overall MASE: 1.2664
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 60.5726
#   Overall MASE: 2.8986
#   Predictions made: 9
# TESTING COUNTRY: France
#
# LEAVE-ONE-COUNTRY-OUT MODEL
# Leave-One-Country-Out Comparison for: France
# Total training samples from other countries: 279
# Test country train samples: 26
# Test country test samples: 9
# Training sequences: 272
#     Iter 0: Using last 5 train values
#     RMSE: 29.8427, MASE: 10.0674
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 43.5256, MASE: 1.9340
#     Iter 2: Using test[1:6]
#     RMSE: 19.8270, MASE: 1.1187
#     Iter 0: Using last 5 training values
#     RMSE: 29.8427, MASE: 10.0674
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 17.1193, MASE: 0.7659
#     Iter 2: Using pred[1:6]
#     RMSE: 6.6754, MASE: 0.3903
#
# Summary for France
#
# Non-Recursive (actual values):
#   Overall RMSE: 32.5483
#   Overall MASE: 1.9226
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 20.2338
#   Overall MASE: 1.1197
#   Predictions made: 9
#
# SINGLE COUNTRY MODEL
#
# Single Country Model for France
# Training samples: 26
# Test samples: 9
# Training sequences: 19
#     Iter 0: Using last 5 train values
#     RMSE: 11.8220, MASE: 3.8813
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 32.6551, MASE: 1.3007
#     Iter 2: Using test[1:6]
#     RMSE: 16.5742, MASE: 0.8542
#     Iter 0: Using last 5 training values
#     RMSE: 11.8220, MASE: 3.8813
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 20.9980, MASE: 0.6721
#     Iter 2: Using pred[1:6]
#     RMSE: 25.6284, MASE: 1.3580
#
# Single Country Summary for France
#
# Non-Recursive (actual values):
#   Overall RMSE: 22.2173
#   Overall MASE: 1.1510
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 20.3100
#   Overall MASE: 1.0474
#   Predictions made: 9
# TESTING COUNTRY: Italy
#
# LEAVE-ONE-COUNTRY-OUT MODEL
# Leave-One-Country-Out Comparison for: Italy
# Total training samples from other countries: 279
# Test country train samples: 26
# Test country test samples: 9
# Training sequences: 272
#     Iter 0: Using last 5 train values
#     RMSE: 16.9529, MASE: 3.5277
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 22.3927, MASE: 0.7401
#     Iter 2: Using test[1:6]
#     RMSE: 29.9272, MASE: 1.7386
#     Iter 0: Using last 5 training values
#     RMSE: 16.9529, MASE: 3.5277
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 21.5387, MASE: 0.8032
#     Iter 2: Using pred[1:6]
#     RMSE: 13.1626, MASE: 0.5457
#
# Summary for Italy
#
# Non-Recursive (actual values):
#   Overall RMSE: 23.6958
#   Overall MASE: 1.2922
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 17.5553
#   Overall MASE: 0.9143
#   Predictions made: 9
#
# SINGLE COUNTRY MODEL
#
# Single Country Model for Italy
# Training samples: 26
# Test samples: 9
# Training sequences: 19
#     Iter 0: Using last 5 train values
#     RMSE: 31.8808, MASE: 7.1783
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 18.2976, MASE: 0.4905
#     Iter 2: Using test[1:6]
#     RMSE: 28.0736, MASE: 1.5759
#     Iter 0: Using last 5 training values
#     RMSE: 31.8808, MASE: 7.1783
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 33.3458, MASE: 1.2799
#     Iter 2: Using pred[1:6]
#     RMSE: 36.6324, MASE: 2.1661
#
# Single Country Summary for Italy
#
# Non-Recursive (actual values):
#   Overall RMSE: 26.7040
#   Overall MASE: 1.4483
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 34.0111
#   Overall MASE: 2.0455
#   Predictions made: 9
# TESTING COUNTRY: Canada
#
# LEAVE-ONE-COUNTRY-OUT MODEL
# Leave-One-Country-Out Comparison for: Canada
# Total training samples from other countries: 279
# Test country train samples: 26
# Test country test samples: 9
# Training sequences: 272
#     Iter 0: Using last 5 train values
#     RMSE: 16.3744, MASE: 1.6114
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 58.0203, MASE: 1.5921
#     Iter 2: Using test[1:6]
#     RMSE: 2.1207, MASE: 0.3028
#     Iter 0: Using last 5 training values
#     RMSE: 16.3744, MASE: 1.6114
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 53.6413, MASE: 1.4227
#     Iter 2: Using pred[1:6]
#     RMSE: 93.3517, MASE: 16.0731
#
# Summary for Canada
#
# Non-Recursive (actual values):
#   Overall RMSE: 34.8280
#   Overall MASE: 1.5016
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 62.8757
#   Overall MASE: 3.5881
#   Predictions made: 9
#
# SINGLE COUNTRY MODEL
#
# Single Country Model for Canada
# Training samples: 26
# Test samples: 9
# Training sequences: 19
#     Iter 0: Using last 5 train values
#     RMSE: 8.2564, MASE: 0.6637
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 26.9890, MASE: 0.7319
#     Iter 2: Using test[1:6]
#     RMSE: 10.7288, MASE: 1.8090
#     Iter 0: Using last 5 training values
#     RMSE: 8.2564, MASE: 0.6637
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 27.9103, MASE: 0.7496
#     Iter 2: Using pred[1:6]
#     RMSE: 37.7228, MASE: 6.4842
#
# Single Country Summary for Canada
#
# Non-Recursive (actual values):
#   Overall RMSE: 17.4325
#   Overall MASE: 0.9076
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 27.5085
#   Overall MASE: 1.5739
#   Predictions made: 9
# TESTING COUNTRY: Australia
#
# LEAVE-ONE-COUNTRY-OUT MODEL
# Leave-One-Country-Out Comparison for: Australia
# Total training samples from other countries: 279
# Test country train samples: 26
# Test country test samples: 9
# Training sequences: 272
#     Iter 0: Using last 5 train values
#     RMSE: 20.9006, MASE: 2.9077
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 10.4653, MASE: 1.1880
#     Iter 2: Using test[1:6]
#     RMSE: 14.4387, MASE: 4.4327
#     Iter 0: Using last 5 training values
#     RMSE: 20.9006, MASE: 2.9077
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 34.7871, MASE: 4.1320
#     Iter 2: Using pred[1:6]
#     RMSE: 45.1861, MASE: 14.8562
#
# Summary for Australia
#
# Non-Recursive (actual values):
#   Overall RMSE: 15.8623
#   Overall MASE: 2.3384
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 35.0655
#   Overall MASE: 5.5222
#   Predictions made: 9
#
# SINGLE COUNTRY MODEL
#
# Single Country Model for Australia
# Training samples: 26
# Test samples: 9
# Training sequences: 19
#     Iter 0: Using last 5 train values
#     RMSE: 28.6347, MASE: 4.2927
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 10.3962, MASE: 1.1459
#     Iter 2: Using test[1:6]
#     RMSE: 7.1660, MASE: 1.6658
#     Iter 0: Using last 5 training values
#     RMSE: 28.6347, MASE: 4.2927
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 39.9800, MASE: 4.7208
#     Iter 2: Using pred[1:6]
#     RMSE: 16.7861, MASE: 5.5108
#
# Single Country Summary for Australia
#
# Non-Recursive (actual values):
#   Overall RMSE: 18.0682
#   Overall MASE: 2.3277
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 30.0007
#   Overall MASE: 4.6841
#   Predictions made: 9
# TESTING COUNTRY: South Korea
#
# LEAVE-ONE-COUNTRY-OUT MODEL
# Leave-One-Country-Out Comparison for: South Korea
# Total training samples from other countries: 280
# Test country train samples: 25
# Test country test samples: 9
# Training sequences: 273
#     Iter 0: Using last 5 train values
#     RMSE: 18.4767, MASE: 1.6899
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 47.0727, MASE: 1.0168
#     Iter 2: Using test[1:6]
#     RMSE: 23.3618, MASE: 1.0740
#     Iter 0: Using last 5 training values
#     RMSE: 18.4767, MASE: 1.6899
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 68.0684, MASE: 1.5862
#     Iter 2: Using pred[1:6]
#     RMSE: 112.0054, MASE: 5.6523
#
# Summary for South Korea
#
# Non-Recursive (actual values):
#   Overall RMSE: 32.1611
#   Overall MASE: 1.2050
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 76.4197
#   Overall MASE: 2.9622
#   Predictions made: 9
#
# SINGLE COUNTRY MODEL
#
# Single Country Model for South Korea
# Training samples: 25
# Test samples: 9
# Training sequences: 18
#     Iter 0: Using last 5 train values
#     RMSE: 18.6903, MASE: 1.3746
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 19.2342, MASE: 0.4400
#     Iter 2: Using test[1:6]
#     RMSE: 16.6468, MASE: 0.7362
#     Iter 0: Using last 5 training values
#     RMSE: 18.6903, MASE: 1.3746
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 29.2912, MASE: 0.7569
#     Iter 2: Using pred[1:6]
#     RMSE: 44.3596, MASE: 2.2693
#
# Single Country Summary for South Korea
#
# Non-Recursive (actual values):
#   Overall RMSE: 18.2245
#   Overall MASE: 0.7113
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 32.5324
#   Overall MASE: 1.3735
#   Predictions made: 9
#
# United States:
#
#   NON_RECURSIVE:
#     LOCO RMSE:    1250.6214
#     Single RMSE: 231.8524
#     Single Country is 439.4% better
#
#   RECURSIVE:
#     LOCO RMSE:    3379.2328
#     Single RMSE: 285.7648
#     Single Country is 1082.5% better
#
# Japan:
#
#   NON_RECURSIVE:
#     LOCO RMSE:    77.6343
#     Single RMSE: 240.0397
#     LOCO is 67.7% better
#
#   RECURSIVE:
#     LOCO RMSE:    180.3522
#     Single RMSE: 236.3830
#     LOCO is 23.7% better
#
# Germany:
#
#   NON_RECURSIVE:
#     LOCO RMSE:    25.4584
#     Single RMSE: 45.4619
#     LOCO is 44.0% better
#
#   RECURSIVE:
#     LOCO RMSE:    21.8447
#     Single RMSE: 67.3176
#     LOCO is 67.5% better
#
# United Kingdom:
#
#   NON_RECURSIVE:
#     LOCO RMSE:    56.6064
#     Single RMSE: 27.4629
#     Single Country is 106.1% better
#
#   RECURSIVE:
#     LOCO RMSE:    131.2772
#     Single RMSE: 60.5726
#     Single Country is 116.7% better
#
# France:
#
#   NON_RECURSIVE:
#     LOCO RMSE:    32.5483
#     Single RMSE: 22.2173
#     Single Country is 46.5% better
#
#   RECURSIVE:
#     LOCO RMSE:    20.2338
#     Single RMSE: 20.3100
#     LOCO is 0.4% better
#
# Italy:
#
#   NON_RECURSIVE:
#     LOCO RMSE:    23.6958
#     Single RMSE: 26.7040
#     LOCO is 11.3% better
#
#   RECURSIVE:
#     LOCO RMSE:    17.5553
#     Single RMSE: 34.0111
#     LOCO is 48.4% better
#
# Canada:
#
#   NON_RECURSIVE:
#     LOCO RMSE:    34.8280
#     Single RMSE: 17.4325
#     Single Country is 99.8% better
#
#   RECURSIVE:
#     LOCO RMSE:    62.8757
#     Single RMSE: 27.5085
#     Single Country is 128.6% better
#
# Australia:
#
#   NON_RECURSIVE:
#     LOCO RMSE:    15.8623
#     Single RMSE: 18.0682
#     LOCO is 12.2% better
#
#   RECURSIVE:
#     LOCO RMSE:    35.0655
#     Single RMSE: 30.0007
#     Single Country is 16.9% better
#
# South Korea:
#
#   NON_RECURSIVE:
#     LOCO RMSE:    32.1611
#     Single RMSE: 18.2245
#     Single Country is 76.5% better
#
#   RECURSIVE:
#     LOCO RMSE:    76.4197
#     Single RMSE: 32.5324
#     Single Country is 134.9% better
# WARNING:tensorflow:From c:\Users\sodjs\RL\venv\lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
#
# Running co2 - LSTM - developing
#
# LOCO vs SINGLE DEVELOPING COUNTRY MODELS
# Target: co2
# Model: build_lstm
# Test size: 9 samples
# Data Shape: (1138, 992)
# TESTING COUNTRY: China
#
# LEAVE-ONE-COUNTRY-OUT MODEL
# Leave-One-Country-Out Comparison for: China
# Total training samples from other countries: 315
# Test country train samples: 26
# Test country test samples: 9
# Training sequences: 308
#     Iter 0: Using last 5 train values
#     RMSE: 910.9307, MASE: 3.7859
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 3843.6508, MASE: 11.8000
#     Iter 2: Using test[1:6]
#     RMSE: 2842.7108, MASE: 8.0941
#     Iter 0: Using last 5 training values
#     RMSE: 910.9307, MASE: 3.7859
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 3962.4156, MASE: 12.8876
#     Iter 2: Using pred[1:6]
#     RMSE: 6297.8679, MASE: 19.0159
#
# Summary for China
#
# Non-Recursive (actual values):
#   Overall RMSE: 2809.7717
#   Overall MASE: 7.2914
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 4327.9584
#   Overall MASE: 11.5153
#   Predictions made: 9
#
# SINGLE COUNTRY MODEL
#
# Single Country Model for China
# Training samples: 26
# Test samples: 9
# Training sequences: 19
#     Iter 0: Using last 5 train values
#     RMSE: 762.5333, MASE: 4.3192
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 966.8545, MASE: 3.1905
#     Iter 2: Using test[1:6]
#     RMSE: 876.7535, MASE: 2.3571
#     Iter 0: Using last 5 training values
#     RMSE: 762.5333, MASE: 4.3192
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 167.7560, MASE: 0.5674
#     Iter 2: Using pred[1:6]
#     RMSE: 235.7187, MASE: 0.6771
#
# Single Country Summary for China
#
# Non-Recursive (actual values):
#   Overall RMSE: 872.7278
#   Overall MASE: 2.6528
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 470.8724
#   Overall MASE: 1.2330
#   Predictions made: 9
# TESTING COUNTRY: Brazil
#
# LEAVE-ONE-COUNTRY-OUT MODEL
# Leave-One-Country-Out Comparison for: Brazil
# Total training samples from other countries: 315
# Test country train samples: 26
# Test country test samples: 9
# Training sequences: 308
#     Iter 0: Using last 5 train values
#     RMSE: 88.6585, MASE: 4.1593
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 50.6401, MASE: 2.9010
#     Iter 2: Using test[1:6]
#     RMSE: 36.7029, MASE: 4.2074
#     Iter 0: Using last 5 training values
#     RMSE: 88.6585, MASE: 4.1593
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 151.1051, MASE: 9.0602
#     Iter 2: Using pred[1:6]
#     RMSE: 141.9924, MASE: 16.8385
#
# Summary for Brazil
#
# Non-Recursive (actual values):
#   Overall RMSE: 62.6414
#   Overall MASE: 2.7682
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 130.1985
#   Overall MASE: 6.1386
#   Predictions made: 9
#
# SINGLE COUNTRY MODEL
#
# Single Country Model for Brazil
# Training samples: 26
# Test samples: 9
# Training sequences: 19
#     Iter 0: Using last 5 train values
#     RMSE: 140.9495, MASE: 6.3269
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 73.1649, MASE: 3.9210
#     Iter 2: Using test[1:6]
#     RMSE: 32.0358, MASE: 3.3133
#     Iter 0: Using last 5 training values
#     RMSE: 140.9495, MASE: 6.3269
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 251.3973, MASE: 14.9731
#     Iter 2: Using pred[1:6]
#     RMSE: 349.0190, MASE: 41.2015
#
# Single Country Summary for Brazil
#
# Non-Recursive (actual values):
#   Overall RMSE: 93.5346
#   Overall MASE: 3.6591
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 261.3309
#   Overall MASE: 11.7769
#   Predictions made: 9
# TESTING COUNTRY: Russia
#
# LEAVE-ONE-COUNTRY-OUT MODEL
# Leave-One-Country-Out Comparison for: Russia
# Total training samples from other countries: 315
# Test country train samples: 26
# Test country test samples: 9
# Training sequences: 308
#     Iter 0: Using last 5 train values
#     RMSE: 70.0706, MASE: 3.0954
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 26.3119, MASE: 0.6521
#     Iter 2: Using test[1:6]
#     RMSE: 171.2770, MASE: 3.0613
#     Iter 0: Using last 5 training values
#     RMSE: 70.0706, MASE: 3.0954
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 130.2059, MASE: 3.2060
#     Iter 2: Using pred[1:6]
#     RMSE: 257.5877, MASE: 4.8125
#
# Summary for Russia
#
# Non-Recursive (actual values):
#   Overall RMSE: 107.9167
#   Overall MASE: 1.8547
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 171.4787
#   Overall MASE: 3.3480
#   Predictions made: 9
#
# SINGLE COUNTRY MODEL
#
# Single Country Model for Russia
# Training samples: 26
# Test samples: 9
# Training sequences: 19
#     Iter 0: Using last 5 train values
#     RMSE: 31.9350, MASE: 1.2660
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 59.9969, MASE: 1.3190
#     Iter 2: Using test[1:6]
#     RMSE: 203.7846, MASE: 3.7886
#     Iter 0: Using last 5 training values
#     RMSE: 31.9350, MASE: 1.2660
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 111.6341, MASE: 2.7057
#     Iter 2: Using pred[1:6]
#     RMSE: 267.7958, MASE: 5.0532
#
# Single Country Summary for Russia
#
# Non-Recursive (actual values):
#   Overall RMSE: 124.0264
#   Overall MASE: 2.1051
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 168.5196
#   Overall MASE: 3.0423
#   Predictions made: 9
# TESTING COUNTRY: India
#
# LEAVE-ONE-COUNTRY-OUT MODEL
# Leave-One-Country-Out Comparison for: India
# Total training samples from other countries: 315
# Test country train samples: 26
# Test country test samples: 9
# Training sequences: 308
#     Iter 0: Using last 5 train values
#     RMSE: 124.3961, MASE: 1.2082
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 366.6576, MASE: 3.0013
#     Iter 2: Using test[1:6]
#     RMSE: 48.9563, MASE: 0.2191
#     Iter 0: Using last 5 training values
#     RMSE: 124.3961, MASE: 1.2082
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 365.5034, MASE: 2.6508
#     Iter 2: Using pred[1:6]
#     RMSE: 532.7464, MASE: 2.7347
#
# Summary for India
#
# Non-Recursive (actual values):
#   Overall RMSE: 225.3212
#   Overall MASE: 1.0475
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 379.8622
#   Overall MASE: 2.0412
#   Predictions made: 9
#
# SINGLE COUNTRY MODEL
#
# Single Country Model for India
# Training samples: 26
# Test samples: 9
# Training sequences: 19
#     Iter 0: Using last 5 train values
#     RMSE: 149.9338, MASE: 1.3695
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 372.4429, MASE: 2.6531
#     Iter 2: Using test[1:6]
#     RMSE: 42.2535, MASE: 0.1600
#     Iter 0: Using last 5 training values
#     RMSE: 149.9338, MASE: 1.3695
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 595.6086, MASE: 5.0797
#     Iter 2: Using pred[1:6]
#     RMSE: 1055.1602, MASE: 5.4159
#
# Single Country Summary for India
#
# Non-Recursive (actual values):
#   Overall RMSE: 233.0803
#   Overall MASE: 0.9755
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 704.8860
#   Overall MASE: 3.7861
#   Predictions made: 9
# TESTING COUNTRY: Mexico
#
# LEAVE-ONE-COUNTRY-OUT MODEL
# Leave-One-Country-Out Comparison for: Mexico
# Total training samples from other countries: 315
# Test country train samples: 26
# Test country test samples: 9
# Training sequences: 308
#     Iter 0: Using last 5 train values
#     RMSE: 42.3592, MASE: 5.0984
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 69.3689, MASE: 2.6054
#     Iter 2: Using test[1:6]
#     RMSE: 34.9145, MASE: 1.9477
#     Iter 0: Using last 5 training values
#     RMSE: 42.3592, MASE: 5.0984
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 126.3402, MASE: 5.8746
#     Iter 2: Using pred[1:6]
#     RMSE: 242.2507, MASE: 13.5320
#
# Summary for Mexico
#
# Non-Recursive (actual values):
#   Overall RMSE: 51.0731
#   Overall MASE: 2.9612
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 159.6262
#   Overall MASE: 9.4221
#   Predictions made: 9
#
# SINGLE COUNTRY MODEL
#
# Single Country Model for Mexico
# Training samples: 26
# Test samples: 9
# Training sequences: 19
#     Iter 0: Using last 5 train values
#     RMSE: 9.5188, MASE: 1.1564
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 12.3518, MASE: 0.5152
#     Iter 2: Using test[1:6]
#     RMSE: 74.3772, MASE: 3.4037
#     Iter 0: Using last 5 training values
#     RMSE: 9.5188, MASE: 1.1564
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 19.9517, MASE: 0.8958
#     Iter 2: Using pred[1:6]
#     RMSE: 48.4692, MASE: 2.3619
#
# Single Country Summary for Mexico
#
# Non-Recursive (actual values):
#   Overall RMSE: 43.8754
#   Overall MASE: 1.8959
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 30.7568
#   Overall MASE: 1.6314
#   Predictions made: 9
# TESTING COUNTRY: Indonesia
#
# LEAVE-ONE-COUNTRY-OUT MODEL
# Leave-One-Country-Out Comparison for: Indonesia
# Total training samples from other countries: 315
# Test country train samples: 26
# Test country test samples: 9
# Training sequences: 308
#     Iter 0: Using last 5 train values
#     RMSE: 30.5227, MASE: 3.1532
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 62.7788, MASE: 1.1659
#     Iter 2: Using test[1:6]
#     RMSE: 64.0550, MASE: 0.9859
#     Iter 0: Using last 5 training values
#     RMSE: 30.5227, MASE: 3.1532
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 43.5785, MASE: 0.7892
#     Iter 2: Using pred[1:6]
#     RMSE: 84.1133, MASE: 1.1714
#
# Summary for Indonesia
#
# Non-Recursive (actual values):
#   Overall RMSE: 54.6988
#   Overall MASE: 1.3585
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 57.4623
#   Overall MASE: 1.2803
#   Predictions made: 9
#
# SINGLE COUNTRY MODEL
#
# Single Country Model for Indonesia
# Training samples: 26
# Test samples: 9
# Training sequences: 19
#     Iter 0: Using last 5 train values
#     RMSE: 114.6942, MASE: 11.0387
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 55.6101, MASE: 0.9057
#     Iter 2: Using test[1:6]
#     RMSE: 348.8003, MASE: 4.7767
#     Iter 0: Using last 5 training values
#     RMSE: 114.6942, MASE: 11.0387
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 135.7205, MASE: 2.5774
#     Iter 2: Using pred[1:6]
#     RMSE: 374.3412, MASE: 5.5258
#
# Single Country Summary for Indonesia
#
# Non-Recursive (actual values):
#   Overall RMSE: 214.4053
#   Overall MASE: 3.9656
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 239.2392
#   Overall MASE: 5.1802
#   Predictions made: 9
# TESTING COUNTRY: Turkey
#
# LEAVE-ONE-COUNTRY-OUT MODEL
# Leave-One-Country-Out Comparison for: Turkey
# Total training samples from other countries: 315
# Test country train samples: 26
# Test country test samples: 9
# Training sequences: 308
#     Iter 0: Using last 5 train values
#     RMSE: 13.3724, MASE: 0.3996
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 55.6867, MASE: 3.6338
#     Iter 2: Using test[1:6]
#     RMSE: 21.1090, MASE: 1.7409
#     Iter 0: Using last 5 training values
#     RMSE: 13.3724, MASE: 0.3996
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 26.8875, MASE: 1.5943
#     Iter 2: Using pred[1:6]
#     RMSE: 40.0753, MASE: 3.2346
#
# Summary for Turkey
#
# Non-Recursive (actual values):
#   Overall RMSE: 35.2393
#   Overall MASE: 1.4901
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 28.9124
#   Overall MASE: 1.2179
#   Predictions made: 9
#
# SINGLE COUNTRY MODEL
#
# Single Country Model for Turkey
# Training samples: 26
# Test samples: 9
# Training sequences: 19
#     Iter 0: Using last 5 train values
#     RMSE: 29.6366, MASE: 1.2010
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 18.2420, MASE: 1.0627
#     Iter 2: Using test[1:6]
#     RMSE: 108.1325, MASE: 10.4732
#     Iter 0: Using last 5 training values
#     RMSE: 29.6366, MASE: 1.2010
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 50.0967, MASE: 3.3519
#     Iter 2: Using pred[1:6]
#     RMSE: 148.1875, MASE: 14.3588
#
# Single Country Summary for Turkey
#
# Non-Recursive (actual values):
#   Overall RMSE: 65.5839
#   Overall MASE: 2.7869
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 91.9194
#   Overall MASE: 4.1487
#   Predictions made: 9
# TESTING COUNTRY: Saudi Arabia
#
# LEAVE-ONE-COUNTRY-OUT MODEL
# Leave-One-Country-Out Comparison for: Saudi Arabia
# Total training samples from other countries: 315
# Test country train samples: 26
# Test country test samples: 9
# Training sequences: 308
#     Iter 0: Using last 5 train values
#     RMSE: 42.8608, MASE: 1.7368
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 80.9104, MASE: 2.5883
#     Iter 2: Using test[1:6]
#     RMSE: 225.4359, MASE: 10.8976
#     Iter 0: Using last 5 training values
#     RMSE: 42.8608, MASE: 1.7368
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 99.8039, MASE: 3.2052
#     Iter 2: Using pred[1:6]
#     RMSE: 283.1336, MASE: 13.8577
#
# Summary for Saudi Arabia
#
# Non-Recursive (actual values):
#   Overall RMSE: 140.4812
#   Overall MASE: 3.6074
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 175.0833
#   Overall MASE: 4.4468
#   Predictions made: 9
#
# SINGLE COUNTRY MODEL
#
# Single Country Model for Saudi Arabia
# Training samples: 26
# Test samples: 9
# Training sequences: 19
#     Iter 0: Using last 5 train values
#     RMSE: 19.3803, MASE: 0.7410
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 10.0737, MASE: 0.2892
#     Iter 2: Using test[1:6]
#     RMSE: 103.8835, MASE: 4.9113
#     Iter 0: Using last 5 training values
#     RMSE: 19.3803, MASE: 0.7410
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 22.6662, MASE: 0.7296
#     Iter 2: Using pred[1:6]
#     RMSE: 65.2902, MASE: 2.4513
#
# Single Country Summary for Saudi Arabia
#
# Non-Recursive (actual values):
#   Overall RMSE: 61.2886
#   Overall MASE: 1.3278
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 41.4414
#   Overall MASE: 0.9432
#   Predictions made: 9
# TESTING COUNTRY: South Africa
#
# LEAVE-ONE-COUNTRY-OUT MODEL
# Leave-One-Country-Out Comparison for: South Africa
# Total training samples from other countries: 315
# Test country train samples: 26
# Test country test samples: 9
# Training sequences: 308
#     Iter 0: Using last 5 train values
#     RMSE: 25.8369, MASE: 1.7566
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 24.2677, MASE: 0.5905
#     Iter 2: Using test[1:6]
#     RMSE: 21.6864, MASE: 1.6707
#     Iter 0: Using last 5 training values
#     RMSE: 25.8369, MASE: 1.7566
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 20.6940, MASE: 0.6574
#     Iter 2: Using pred[1:6]
#     RMSE: 8.7755, MASE: 0.6021
#
# Summary for South Africa
#
# Non-Recursive (actual values):
#   Overall RMSE: 23.9914
#   Overall MASE: 1.3249
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 19.7720
#   Overall MASE: 1.0936
#   Predictions made: 9
#
# SINGLE COUNTRY MODEL
#
# Single Country Model for South Africa
# Training samples: 26
# Test samples: 9
# Training sequences: 19
#     Iter 0: Using last 5 train values
#     RMSE: 35.9925, MASE: 2.3718
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 19.9756, MASE: 0.6175
#     Iter 2: Using test[1:6]
#     RMSE: 46.7382, MASE: 3.7903
#     Iter 0: Using last 5 training values
#     RMSE: 35.9925, MASE: 2.3718
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 69.2846, MASE: 2.2424
#     Iter 2: Using pred[1:6]
#     RMSE: 143.1921, MASE: 11.8829
#
# Single Country Summary for South Africa
#
# Non-Recursive (actual values):
#   Overall RMSE: 35.9581
#   Overall MASE: 2.0679
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 94.1626
#   Overall MASE: 5.1743
#   Predictions made: 9
# TESTING COUNTRY: Argentina
#
# LEAVE-ONE-COUNTRY-OUT MODEL
# Leave-One-Country-Out Comparison for: Argentina
# Total training samples from other countries: 315
# Test country train samples: 26
# Test country test samples: 9
# Training sequences: 308
#     Iter 0: Using last 5 train values
#     RMSE: 9.7555, MASE: 3.7877
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 14.2145, MASE: 1.3478
#     Iter 2: Using test[1:6]
#     RMSE: 46.9560, MASE: 4.3586
#     Iter 0: Using last 5 training values
#     RMSE: 9.7555, MASE: 3.7877
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 19.1988, MASE: 2.1870
#     Iter 2: Using pred[1:6]
#     RMSE: 20.7072, MASE: 1.7450
#
# Summary for Argentina
#
# Non-Recursive (actual values):
#   Overall RMSE: 28.8796
#   Overall MASE: 2.3798
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 17.2487
#   Overall MASE: 1.6117
#   Predictions made: 9
#
# SINGLE COUNTRY MODEL
#
# Single Country Model for Argentina
# Training samples: 26
# Test samples: 9
# Training sequences: 19
#     Iter 0: Using last 5 train values
#     RMSE: 6.8757, MASE: 2.2222
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 19.6538, MASE: 2.2641
#     Iter 2: Using test[1:6]
#     RMSE: 24.2209, MASE: 2.2094
#     Iter 0: Using last 5 training values
#     RMSE: 6.8757, MASE: 2.2222
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 31.1029, MASE: 3.8274
#     Iter 2: Using pred[1:6]
#     RMSE: 23.1284, MASE: 2.0992
#
# Single Country Summary for Argentina
#
# Non-Recursive (actual values):
#   Overall RMSE: 18.4409
#   Overall MASE: 1.6745
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 22.7273
#   Overall MASE: 2.0690
#   Predictions made: 9
#
# China:
#
#   NON_RECURSIVE:
#     LOCO RMSE:    2809.7717
#     Single RMSE: 872.7278
#     Single Country is 222.0% better
#
#   RECURSIVE:
#     LOCO RMSE:    4327.9584
#     Single RMSE: 470.8724
#     Single Country is 819.1% better
#
# Brazil:
#
#   NON_RECURSIVE:
#     LOCO RMSE:    62.6414
#     Single RMSE: 93.5346
#     LOCO is 33.0% better
#
#   RECURSIVE:
#     LOCO RMSE:    130.1985
#     Single RMSE: 261.3309
#     LOCO is 50.2% better
#
# Russia:
#
#   NON_RECURSIVE:
#     LOCO RMSE:    107.9167
#     Single RMSE: 124.0264
#     LOCO is 13.0% better
#
#   RECURSIVE:
#     LOCO RMSE:    171.4787
#     Single RMSE: 168.5196
#     Single Country is 1.8% better
#
# India:
#
#   NON_RECURSIVE:
#     LOCO RMSE:    225.3212
#     Single RMSE: 233.0803
#     LOCO is 3.3% better
#
#   RECURSIVE:
#     LOCO RMSE:    379.8622
#     Single RMSE: 704.8860
#     LOCO is 46.1% better
#
# Mexico:
#
#   NON_RECURSIVE:
#     LOCO RMSE:    51.0731
#     Single RMSE: 43.8754
#     Single Country is 16.4% better
#
#   RECURSIVE:
#     LOCO RMSE:    159.6262
#     Single RMSE: 30.7568
#     Single Country is 419.0% better
#
# Indonesia:
#
#   NON_RECURSIVE:
#     LOCO RMSE:    54.6988
#     Single RMSE: 214.4053
#     LOCO is 74.5% better
#
#   RECURSIVE:
#     LOCO RMSE:    57.4623
#     Single RMSE: 239.2392
#     LOCO is 76.0% better
#
# Turkey:
#
#   NON_RECURSIVE:
#     LOCO RMSE:    35.2393
#     Single RMSE: 65.5839
#     LOCO is 46.3% better
#
#   RECURSIVE:
#     LOCO RMSE:    28.9124
#     Single RMSE: 91.9194
#     LOCO is 68.5% better
#
# Saudi Arabia:
#
#   NON_RECURSIVE:
#     LOCO RMSE:    140.4812
#     Single RMSE: 61.2886
#     Single Country is 129.2% better
#
#   RECURSIVE:
#     LOCO RMSE:    175.0833
#     Single RMSE: 41.4414
#     Single Country is 322.5% better
#
# South Africa:
#
#   NON_RECURSIVE:
#     LOCO RMSE:    23.9914
#     Single RMSE: 35.9581
#     LOCO is 33.3% better
#
#   RECURSIVE:
#     LOCO RMSE:    19.7720
#     Single RMSE: 94.1626
#     LOCO is 79.0% better
#
# Argentina:
#
#   NON_RECURSIVE:
#     LOCO RMSE:    28.8796
#     Single RMSE: 18.4409
#     Single Country is 56.6% better
#
#   RECURSIVE:
#     LOCO RMSE:    17.2487
#     Single RMSE: 22.7273
#     LOCO is 24.1% better
#
# Running co2 - Bi-LSTM - developed
#
# LOCO vs SINGLE DEVELOPED COUNTRY MODELS
# Target: co2
# Model: build_bilstm
# Test size: 9 samples
# Data Shape: (1138, 992)
# TESTING COUNTRY: United States
#
# LEAVE-ONE-COUNTRY-OUT MODEL
# Leave-One-Country-Out Comparison for: United States
# Total training samples from other countries: 279
# Test country train samples: 26
# Test country test samples: 9
# Training sequences: 272
#     Iter 0: Using last 5 train values
#     RMSE: 1984.4752, MASE: 23.1563
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 1839.5885, MASE: 5.3602
#     Iter 2: Using test[1:6]
#     RMSE: 2237.3353, MASE: 20.5244
#     Iter 0: Using last 5 training values
#     RMSE: 1984.4752, MASE: 23.1563
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 2777.3693, MASE: 8.2873
#     Iter 2: Using pred[1:6]
#     RMSE: 3036.1570, MASE: 28.2922
#
# Summary for United States
#
# Non-Recursive (actual values):
#   Overall RMSE: 2027.1406
#   Overall MASE: 10.2783
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 2637.5602
#   Overall MASE: 13.4302
#   Predictions made: 9
#
# SINGLE COUNTRY MODEL
#
# Single Country Model for United States
# Training samples: 26
# Test samples: 9
# Training sequences: 19
#     Iter 0: Using last 5 train values
#     RMSE: 216.6224, MASE: 2.3286
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 318.7794, MASE: 0.6508
#     Iter 2: Using test[1:6]
#     RMSE: 210.2172, MASE: 1.7405
#     Iter 0: Using last 5 training values
#     RMSE: 216.6224, MASE: 2.3286
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 534.9257, MASE: 1.4233
#     Iter 2: Using pred[1:6]
#     RMSE: 961.6939, MASE: 8.7121
#
# Single Country Summary for United States
#
# Non-Recursive (actual values):
#   Overall RMSE: 253.4672
#   Overall MASE: 1.0378
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 647.5405
#   Overall MASE: 2.7912
#   Predictions made: 9
# TESTING COUNTRY: Japan
#
# LEAVE-ONE-COUNTRY-OUT MODEL
# Leave-One-Country-Out Comparison for: Japan
# Total training samples from other countries: 279
# Test country train samples: 26
# Test country test samples: 9
# Training sequences: 272
#     Iter 0: Using last 5 train values
#     RMSE: 46.2878, MASE: 2.5420
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 344.1838, MASE: 6.6251
#     Iter 2: Using test[1:6]
#     RMSE: 1152.4006, MASE: 31.5176
#     Iter 0: Using last 5 training values
#     RMSE: 46.2878, MASE: 2.5420
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 308.8492, MASE: 5.9069
#     Iter 2: Using pred[1:6]
#     RMSE: 1241.3956, MASE: 33.9450
#
# Summary for Japan
#
# Non-Recursive (actual values):
#   Overall RMSE: 694.8938
#   Overall MASE: 14.7689
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 739.0520
#   Overall MASE: 15.2702
#   Predictions made: 9
#
# SINGLE COUNTRY MODEL
#
# Single Country Model for Japan
# Training samples: 26
# Test samples: 9
# Training sequences: 19
#     Iter 0: Using last 5 train values
#     RMSE: 93.5204, MASE: 5.0285
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 80.7042, MASE: 1.5588
#     Iter 2: Using test[1:6]
#     RMSE: 60.6022, MASE: 1.2388
#     Iter 0: Using last 5 training values
#     RMSE: 93.5204, MASE: 5.0285
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 105.2982, MASE: 1.9504
#     Iter 2: Using pred[1:6]
#     RMSE: 49.7405, MASE: 1.1411
#
# Single Country Summary for Japan
#
# Non-Recursive (actual values):
#   Overall RMSE: 79.4394
#   Overall MASE: 2.0639
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 86.2321
#   Overall MASE: 2.2216
#   Predictions made: 9
# TESTING COUNTRY: Germany
#
# LEAVE-ONE-COUNTRY-OUT MODEL
# Leave-One-Country-Out Comparison for: Germany
# Total training samples from other countries: 279
# Test country train samples: 26
# Test country test samples: 9
# Training sequences: 272
#     Iter 0: Using last 5 train values
#     RMSE: 42.6741, MASE: 5.1812
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 52.4530, MASE: 0.8503
#     Iter 2: Using test[1:6]
#     RMSE: 25.1126, MASE: 0.5502
#     Iter 0: Using last 5 training values
#     RMSE: 42.6741, MASE: 5.1812
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 26.1819, MASE: 0.3364
#     Iter 2: Using pred[1:6]
#     RMSE: 32.9812, MASE: 0.6863
#
# Summary for Germany
#
# Non-Recursive (actual values):
#   Overall RMSE: 41.6455
#   Overall MASE: 1.1279
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 34.6137
#   Overall MASE: 0.8961
#   Predictions made: 9
#
# SINGLE COUNTRY MODEL
#
# Single Country Model for Germany
# Training samples: 26
# Test samples: 9
# Training sequences: 19
#     Iter 0: Using last 5 train values
#     RMSE: 13.7594, MASE: 1.5203
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 58.1917, MASE: 0.8747
#     Iter 2: Using test[1:6]
#     RMSE: 41.6029, MASE: 1.0040
#     Iter 0: Using last 5 training values
#     RMSE: 13.7594, MASE: 1.5203
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 55.0469, MASE: 0.8472
#     Iter 2: Using pred[1:6]
#     RMSE: 80.9592, MASE: 1.6908
#
# Single Country Summary for Germany
#
# Non-Recursive (actual values):
#   Overall RMSE: 42.0571
#   Overall MASE: 1.0311
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 57.0785
#   Overall MASE: 1.3007
#   Predictions made: 9
# TESTING COUNTRY: United Kingdom
#
# LEAVE-ONE-COUNTRY-OUT MODEL
# Leave-One-Country-Out Comparison for: United Kingdom
# Total training samples from other countries: 279
# Test country train samples: 26
# Test country test samples: 9
# Training sequences: 272
#     Iter 0: Using last 5 train values
#     RMSE: 62.2381, MASE: 3.3783
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 40.9027, MASE: 1.3328
#     Iter 2: Using test[1:6]
#     RMSE: 28.1910, MASE: 1.3991
#     Iter 0: Using last 5 training values
#     RMSE: 62.2381, MASE: 3.3783
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 107.9575, MASE: 3.9775
#     Iter 2: Using pred[1:6]
#     RMSE: 143.3175, MASE: 7.1639
#
# Summary for United Kingdom
#
# Non-Recursive (actual values):
#   Overall RMSE: 45.9759
#   Overall MASE: 2.1229
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 109.6484
#   Overall MASE: 5.3158
#   Predictions made: 9
#
# SINGLE COUNTRY MODEL
#
# Single Country Model for United Kingdom
# Training samples: 26
# Test samples: 9
# Training sequences: 19
#     Iter 0: Using last 5 train values
#     RMSE: 28.0242, MASE: 1.4709
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 31.4846, MASE: 1.0973
#     Iter 2: Using test[1:6]
#     RMSE: 17.6916, MASE: 0.6893
#     Iter 0: Using last 5 training values
#     RMSE: 28.0242, MASE: 1.4709
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 44.9167, MASE: 1.6030
#     Iter 2: Using pred[1:6]
#     RMSE: 64.0469, MASE: 3.1770
#
# Single Country Summary for United Kingdom
#
# Non-Recursive (actual values):
#   Overall RMSE: 26.3921
#   Overall MASE: 1.1913
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 47.9752
#   Overall MASE: 2.2746
#   Predictions made: 9
# TESTING COUNTRY: France
#
# LEAVE-ONE-COUNTRY-OUT MODEL
# Leave-One-Country-Out Comparison for: France
# Total training samples from other countries: 279
# Test country train samples: 26
# Test country test samples: 9
# Training sequences: 272
#     Iter 0: Using last 5 train values
#     RMSE: 9.5892, MASE: 2.6044
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 51.1268, MASE: 2.3228
#     Iter 2: Using test[1:6]
#     RMSE: 25.1837, MASE: 1.4513
#     Iter 0: Using last 5 training values
#     RMSE: 9.5892, MASE: 2.6044
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 36.1302, MASE: 1.5309
#     Iter 2: Using pred[1:6]
#     RMSE: 28.4282, MASE: 1.6767
#
# Summary for France
#
# Non-Recursive (actual values):
#   Overall RMSE: 33.3672
#   Overall MASE: 1.7595
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 27.1140
#   Overall MASE: 1.4789
#   Predictions made: 9
#
# SINGLE COUNTRY MODEL
#
# Single Country Model for France
# Training samples: 26
# Test samples: 9
# Training sequences: 19
#     Iter 0: Using last 5 train values
#     RMSE: 9.7546, MASE: 3.3138
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 38.5308, MASE: 1.7984
#     Iter 2: Using test[1:6]
#     RMSE: 12.1970, MASE: 0.7064
#     Iter 0: Using last 5 training values
#     RMSE: 9.7546, MASE: 3.3138
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 25.2707, MASE: 1.1027
#     Iter 2: Using pred[1:6]
#     RMSE: 44.0867, MASE: 2.6488
#
# Single Country Summary for France
#
# Non-Recursive (actual values):
#   Overall RMSE: 24.0037
#   Overall MASE: 1.2899
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 29.8742
#   Overall MASE: 1.6830
#   Predictions made: 9
# TESTING COUNTRY: Italy
#
# LEAVE-ONE-COUNTRY-OUT MODEL
# Leave-One-Country-Out Comparison for: Italy
# Total training samples from other countries: 279
# Test country train samples: 26
# Test country test samples: 9
# Training sequences: 272
#     Iter 0: Using last 5 train values
#     RMSE: 26.4707, MASE: 6.1608
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 13.6865, MASE: 0.5284
#     Iter 2: Using test[1:6]
#     RMSE: 33.4318, MASE: 2.0444
#     Iter 0: Using last 5 training values
#     RMSE: 26.4707, MASE: 6.1608
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 28.2941, MASE: 1.0590
#     Iter 2: Using pred[1:6]
#     RMSE: 39.5553, MASE: 2.4424
#
# Summary for Italy
#
# Non-Recursive (actual values):
#   Overall RMSE: 25.8567
#   Overall MASE: 1.5342
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 31.9681
#   Overall MASE: 1.9360
#   Predictions made: 9
#
# SINGLE COUNTRY MODEL
#
# Single Country Model for Italy
# Training samples: 26
# Test samples: 9
# Training sequences: 19
#     Iter 0: Using last 5 train values
#     RMSE: 27.6552, MASE: 5.9594
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 19.0067, MASE: 0.6786
#     Iter 2: Using test[1:6]
#     RMSE: 32.4094, MASE: 1.8871
#     Iter 0: Using last 5 training values
#     RMSE: 27.6552, MASE: 5.9594
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 26.3881, MASE: 0.9922
#     Iter 2: Using pred[1:6]
#     RMSE: 36.2592, MASE: 2.1041
#
# Single Country Summary for Italy
#
# Non-Recursive (actual values):
#   Overall RMSE: 26.9347
#   Overall MASE: 1.5367
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 30.4186
#   Overall MASE: 1.7680
#   Predictions made: 9
# TESTING COUNTRY: Canada
#
# LEAVE-ONE-COUNTRY-OUT MODEL
# Leave-One-Country-Out Comparison for: Canada
# Total training samples from other countries: 279
# Test country train samples: 26
# Test country test samples: 9
# Training sequences: 272
#     Iter 0: Using last 5 train values
#     RMSE: 44.4192, MASE: 4.6183
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 59.8371, MASE: 1.4040
#     Iter 2: Using test[1:6]
#     RMSE: 8.5491, MASE: 1.2381
#     Iter 0: Using last 5 training values
#     RMSE: 44.4192, MASE: 4.6183
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 107.9280, MASE: 3.3609
#     Iter 2: Using pred[1:6]
#     RMSE: 169.7613, MASE: 29.1665
#
# Summary for Canada
#
# Non-Recursive (actual values):
#   Overall RMSE: 43.3076
#   Overall MASE: 2.1339
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 118.9404
#   Overall MASE: 7.4161
#   Predictions made: 9
#
# SINGLE COUNTRY MODEL
#
# Single Country Model for Canada
# Training samples: 26
# Test samples: 9
# Training sequences: 19
#     Iter 0: Using last 5 train values
#     RMSE: 10.9634, MASE: 1.0068
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 30.0457, MASE: 0.7252
#     Iter 2: Using test[1:6]
#     RMSE: 12.7050, MASE: 2.1318
#     Iter 0: Using last 5 training values
#     RMSE: 10.9634, MASE: 1.0068
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 31.6472, MASE: 0.7143
#     Iter 2: Using pred[1:6]
#     RMSE: 45.6005, MASE: 7.8371
#
# Single Country Summary for Canada
#
# Non-Recursive (actual values):
#   Overall RMSE: 19.8692
#   Overall MASE: 1.0204
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 32.6657
#   Overall MASE: 1.8106
#   Predictions made: 9
# TESTING COUNTRY: Australia
#
# LEAVE-ONE-COUNTRY-OUT MODEL
# Leave-One-Country-Out Comparison for: Australia
# Total training samples from other countries: 279
# Test country train samples: 26
# Test country test samples: 9
# Training sequences: 272
#     Iter 0: Using last 5 train values
#     RMSE: 13.4720, MASE: 1.6564
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 17.6332, MASE: 1.9342
#     Iter 2: Using test[1:6]
#     RMSE: 25.7457, MASE: 7.4949
#     Iter 0: Using last 5 training values
#     RMSE: 13.4720, MASE: 1.6564
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 21.3805, MASE: 2.0511
#     Iter 2: Using pred[1:6]
# ...
#     Iter 0: Using last 5 training values
#     RMSE: 513.4645, MASE: 4.2208
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 1181.8622, MASE: 6.6787
#     Iter 2: Using pred[1:6]
#     RMSE: 1933.6114, MASE: 10.7198
#
# Summary for Russia
#
# Non-Recursive (actual values):
#   Overall RMSE: 802.5836
#   Overall MASE: 3.9202
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 1341.5535
#   Overall MASE: 6.4021
#   Predictions made: 9
#
# SINGLE COUNTRY MODEL
#
# Single Country Model for Russia
# Training samples: 26
# Test samples: 9
# Training sequences: 19
#     Iter 0: Using last 5 train values
#     RMSE: 188.4172, MASE: 1.5087
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 263.3791, MASE: 1.2923
#     Iter 2: Using test[1:6]
#     RMSE: 757.5891, MASE: 4.1570
#     Iter 0: Using last 5 training values
#     RMSE: 188.4172, MASE: 1.5087
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 257.3879, MASE: 1.2683
#     Iter 2: Using pred[1:6]
#     RMSE: 806.4653, MASE: 4.4357
#
# Single Country Summary for Russia
#
# Non-Recursive (actual values):
#   Overall RMSE: 475.6787
#   Overall MASE: 2.0424
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 500.7114
#   Overall MASE: 2.1250
#   Predictions made: 9
# TESTING COUNTRY: India
#
# LEAVE-ONE-COUNTRY-OUT MODEL
# Leave-One-Country-Out Comparison for: India
# Total training samples from other countries: 315
# Test country train samples: 26
# Test country test samples: 9
# Training sequences: 308
#     Iter 0: Using last 5 train values
#     RMSE: 202.5962, MASE: 0.5691
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 787.0645, MASE: 1.6036
#     Iter 2: Using test[1:6]
#     RMSE: 333.5324, MASE: 0.4588
#     Iter 0: Using last 5 training values
#     RMSE: 202.5962, MASE: 0.5691
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 607.4149, MASE: 1.1327
#     Iter 2: Using pred[1:6]
#     RMSE: 1532.1660, MASE: 2.4171
#
# Summary for India
#
# Non-Recursive (actual values):
#   Overall RMSE: 507.2014
#   Overall MASE: 0.7234
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 958.7371
#   Overall MASE: 1.4491
#   Predictions made: 9
#
# SINGLE COUNTRY MODEL
#
# Single Country Model for India
# Training samples: 26
# Test samples: 9
# Training sequences: 19
#     Iter 0: Using last 5 train values
#     RMSE: 203.2109, MASE: 0.5122
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 797.5519, MASE: 1.6495
#     Iter 2: Using test[1:6]
#     RMSE: 104.6184, MASE: 0.1649
#     Iter 0: Using last 5 training values
#     RMSE: 203.2109, MASE: 0.5122
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 1076.2240, MASE: 2.5761
#     Iter 2: Using pred[1:6]
#     RMSE: 1799.2189, MASE: 2.8688
#
# Single Country Summary for India
#
# Non-Recursive (actual values):
#   Overall RMSE: 479.0020
#   Overall MASE: 0.5953
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 1216.1060
#   Overall MASE: 1.9858
#   Predictions made: 9
# TESTING COUNTRY: Mexico
#
# LEAVE-ONE-COUNTRY-OUT MODEL
# Leave-One-Country-Out Comparison for: Mexico
# Total training samples from other countries: 315
# Test country train samples: 26
# Test country test samples: 9
# Training sequences: 308
#     Iter 0: Using last 5 train values
#     RMSE: 40.5024, MASE: 0.8741
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 295.4587, MASE: 2.0855
#     Iter 2: Using test[1:6]
#     RMSE: 93.0784, MASE: 1.0700
#     Iter 0: Using last 5 training values
#     RMSE: 40.5024, MASE: 0.8741
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 311.0706, MASE: 2.2633
#     Iter 2: Using pred[1:6]
#     RMSE: 428.9940, MASE: 4.9839
#
# Summary for Mexico
#
# Non-Recursive (actual values):
#   Overall RMSE: 180.3699
#   Overall MASE: 1.5017
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 306.8340
#   Overall MASE: 2.9759
#   Predictions made: 9
#
# SINGLE COUNTRY MODEL
#
# Single Country Model for Mexico
# Training samples: 26
# Test samples: 9
# Training sequences: 19
#     Iter 0: Using last 5 train values
#     RMSE: 16.1310, MASE: 0.2925
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 198.6457, MASE: 1.5212
#     Iter 2: Using test[1:6]
#     RMSE: 202.2770, MASE: 2.2970
#     Iter 0: Using last 5 training values
#     RMSE: 16.1310, MASE: 0.2925
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 202.2463, MASE: 1.5460
#     Iter 2: Using pred[1:6]
#     RMSE: 134.3637, MASE: 1.5102
#
# Single Country Summary for Mexico
#
# Non-Recursive (actual values):
#   Overall RMSE: 163.9475
#   Overall MASE: 1.5721
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 140.4960
#   Overall MASE: 1.3037
#   Predictions made: 9
# TESTING COUNTRY: Indonesia
#
# LEAVE-ONE-COUNTRY-OUT MODEL
# Leave-One-Country-Out Comparison for: Indonesia
# Total training samples from other countries: 315
# Test country train samples: 26
# Test country test samples: 9
# Training sequences: 308
#     Iter 0: Using last 5 train values
#     RMSE: 231.9641, MASE: 4.0391
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 144.3839, MASE: 0.9417
#     Iter 2: Using test[1:6]
#     RMSE: 363.3889, MASE: 1.0442
#     Iter 0: Using last 5 training values
#     RMSE: 231.9641, MASE: 4.0391
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 381.2022, MASE: 2.4688
#     Iter 2: Using pred[1:6]
#     RMSE: 382.3727, MASE: 1.0292
#
# Summary for Indonesia
#
# Non-Recursive (actual values):
#   Overall RMSE: 262.4916
#   Overall MASE: 1.4259
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 339.2793
#   Overall MASE: 1.8925
#   Predictions made: 9
#
# SINGLE COUNTRY MODEL
#
# Single Country Model for Indonesia
# Training samples: 26
# Test samples: 9
# Training sequences: 19
#     Iter 0: Using last 5 train values
#     RMSE: 96.0398, MASE: 1.6344
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 73.1866, MASE: 0.5004
#     Iter 2: Using test[1:6]
#     RMSE: 574.4968, MASE: 1.6413
#     Iter 0: Using last 5 training values
#     RMSE: 96.0398, MASE: 1.6344
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 191.4470, MASE: 1.2460
#     Iter 2: Using pred[1:6]
#     RMSE: 598.6134, MASE: 1.6459
#
# Single Country Summary for Indonesia
#
# Non-Recursive (actual values):
#   Overall RMSE: 338.9329
#   Overall MASE: 1.4094
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 367.0666
#   Overall MASE: 1.6449
#   Predictions made: 9
# TESTING COUNTRY: Turkey
#
# LEAVE-ONE-COUNTRY-OUT MODEL
# Leave-One-Country-Out Comparison for: Turkey
# Total training samples from other countries: 315
# Test country train samples: 26
# Test country test samples: 9
# Training sequences: 308
#     Iter 0: Using last 5 train values
#     RMSE: 158.6965, MASE: 1.5610
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 58.7658, MASE: 1.2188
#     Iter 2: Using test[1:6]
#     RMSE: 95.9939, MASE: 3.3990
#     Iter 0: Using last 5 training values
#     RMSE: 158.6965, MASE: 1.5610
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 257.0321, MASE: 5.7702
#     Iter 2: Using pred[1:6]
#     RMSE: 227.1752, MASE: 9.0244
#
# Summary for Turkey
#
# Non-Recursive (actual values):
#   Overall RMSE: 112.3281
#   Overall MASE: 1.6644
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 218.2190
#   Overall MASE: 3.5938
#   Predictions made: 9
#
# SINGLE COUNTRY MODEL
#
# Single Country Model for Turkey
# Training samples: 26
# Test samples: 9
# Training sequences: 19
#     Iter 0: Using last 5 train values
#     RMSE: 122.2440, MASE: 1.1358
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 118.4690, MASE: 2.6673
#     Iter 2: Using test[1:6]
#     RMSE: 88.0109, MASE: 3.3237
#     Iter 0: Using last 5 training values
#     RMSE: 122.2440, MASE: 1.1358
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 79.0832, MASE: 1.7580
#     Iter 2: Using pred[1:6]
#     RMSE: 208.9097, MASE: 8.6591
#
# Single Country Summary for Turkey
#
# Non-Recursive (actual values):
#   Overall RMSE: 110.6412
#   Overall MASE: 1.7807
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 147.0159
#   Overall MASE: 2.2809
#   Predictions made: 9
# TESTING COUNTRY: Saudi Arabia
#
# LEAVE-ONE-COUNTRY-OUT MODEL
# Leave-One-Country-Out Comparison for: Saudi Arabia
# Total training samples from other countries: 315
# Test country train samples: 26
# Test country test samples: 9
# Training sequences: 308
#     Iter 0: Using last 5 train values
#     RMSE: 309.0458, MASE: 4.7455
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 48.7337, MASE: 0.3980
#     Iter 2: Using test[1:6]
#     RMSE: 581.3583, MASE: 4.3830
#     Iter 0: Using last 5 training values
#     RMSE: 309.0458, MASE: 4.7455
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 305.9792, MASE: 2.8105
#     Iter 2: Using pred[1:6]
#     RMSE: 769.1452, MASE: 6.1092
#
# Summary for Saudi Arabia
#
# Non-Recursive (actual values):
#   Overall RMSE: 381.1656
#   Overall MASE: 3.0530
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 510.1363
#   Overall MASE: 4.6992
#   Predictions made: 9
#
# SINGLE COUNTRY MODEL
#
# Single Country Model for Saudi Arabia
# Training samples: 26
# Test samples: 9
# Training sequences: 19
#     Iter 0: Using last 5 train values
#     RMSE: 318.2936, MASE: 4.4655
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 597.2595, MASE: 5.0053
#     Iter 2: Using test[1:6]
#     RMSE: 59.4030, MASE: 0.3526
#     Iter 0: Using last 5 training values
#     RMSE: 318.2936, MASE: 4.4655
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 1113.7091, MASE: 10.0138
#     Iter 2: Using pred[1:6]
#     RMSE: 1580.0665, MASE: 13.1431
#
# Single Country Summary for Saudi Arabia
#
# Non-Recursive (actual values):
#   Overall RMSE: 392.2408
#   Overall MASE: 3.0357
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 1131.1158
#   Overall MASE: 10.3478
#   Predictions made: 9
# TESTING COUNTRY: South Africa
#
# LEAVE-ONE-COUNTRY-OUT MODEL
# Leave-One-Country-Out Comparison for: South Africa
# Total training samples from other countries: 315
# Test country train samples: 26
# Test country test samples: 9
# Training sequences: 308
#     Iter 0: Using last 5 train values
#     RMSE: 18.5217, MASE: 0.3874
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 112.1493, MASE: 1.1742
#     Iter 2: Using test[1:6]
#     RMSE: 20.5391, MASE: 0.6364
#     Iter 0: Using last 5 training values
#     RMSE: 18.5217, MASE: 0.3874
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 104.1337, MASE: 1.0471
#     Iter 2: Using pred[1:6]
#     RMSE: 187.0796, MASE: 6.4437
#
# Summary for South Africa
#
# Non-Recursive (actual values):
#   Overall RMSE: 66.6892
#   Overall MASE: 0.9359
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 124.0775
#   Overall MASE: 2.1276
#   Predictions made: 9
#
# SINGLE COUNTRY MODEL
#
# Single Country Model for South Africa
# Training samples: 26
# Test samples: 9
# Training sequences: 19
#     Iter 0: Using last 5 train values
#     RMSE: 39.3659, MASE: 0.8980
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 84.4442, MASE: 0.9184
#     Iter 2: Using test[1:6]
#     RMSE: 39.7559, MASE: 1.3298
#     Iter 0: Using last 5 training values
#     RMSE: 39.3659, MASE: 0.8980
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 73.3238, MASE: 0.7539
#     Iter 2: Using pred[1:6]
#     RMSE: 144.8384, MASE: 4.9850
#
# Single Country Summary for South Africa
#
# Non-Recursive (actual values):
#   Overall RMSE: 58.4837
#   Overall MASE: 1.0707
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 96.4438
#   Overall MASE: 1.7708
#   Predictions made: 9
# TESTING COUNTRY: Argentina
#
# LEAVE-ONE-COUNTRY-OUT MODEL
# Leave-One-Country-Out Comparison for: Argentina
# Total training samples from other countries: 315
# Test country train samples: 26
# Test country test samples: 9
# Training sequences: 308
#     Iter 0: Using last 5 train values
#     RMSE: 8.9572, MASE: 2.9155
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 99.9715, MASE: 1.4434
#     Iter 2: Using test[1:6]
#     RMSE: 85.9266, MASE: 2.0431
#     Iter 0: Using last 5 training values
#     RMSE: 8.9572, MASE: 2.9155
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 104.9787, MASE: 1.5399
#     Iter 2: Using pred[1:6]
#     RMSE: 86.5107, MASE: 2.0617
#
# Summary for Argentina
#
# Non-Recursive (actual values):
#   Overall RMSE: 76.2844
#   Overall MASE: 1.5572
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 78.7080
#   Overall MASE: 1.6136
#   Predictions made: 9
#
# SINGLE COUNTRY MODEL
#
# Single Country Model for Argentina
# Training samples: 26
# Test samples: 9
# Training sequences: 19
#     Iter 0: Using last 5 train values
#     RMSE: 71.6739, MASE: 23.0916
#     Iter 1: Using last 2 train + test[0:3]
#     RMSE: 153.0178, MASE: 2.2838
#     Iter 2: Using test[1:6]
#     RMSE: 74.3073, MASE: 1.7801
#     Iter 0: Using last 5 training values
#     RMSE: 71.6739, MASE: 23.0916
#     Iter 1: Using last 2 training + pred[0:3]
#     RMSE: 256.8117, MASE: 4.2431
#     Iter 2: Using pred[1:6]
#     RMSE: 300.7688, MASE: 7.4315
#
# Single Country Summary for Argentina
#
# Non-Recursive (actual values):
#   Overall RMSE: 106.5726
#   Overall MASE: 2.3981
#   Predictions made: 9
#
# Recursive (actual values):
#   Overall RMSE: 232.0570
#   Overall MASE: 5.4565
#   Predictions made: 9
#
# China:
#
#   NON_RECURSIVE:
#     LOCO RMSE:    16949.6333
#     Single RMSE: 6529.5299
#     Single Country is 159.6% better
#
#   RECURSIVE:
#     LOCO RMSE:    25182.9445
#     Single RMSE: 16971.5626
#     Single Country is 48.4% better
#
# Brazil:
#
#   NON_RECURSIVE:
#     LOCO RMSE:    157.7462
#     Single RMSE: 219.6594
#     LOCO is 28.2% better
#
#   RECURSIVE:
#     LOCO RMSE:    364.8319
#     Single RMSE: 608.3145
#     LOCO is 40.0% better
#
# Russia:
#
#   NON_RECURSIVE:
#     LOCO RMSE:    802.5836
#     Single RMSE: 475.6787
#     Single Country is 68.7% better
#
#   RECURSIVE:
#     LOCO RMSE:    1341.5535
#     Single RMSE: 500.7114
#     Single Country is 167.9% better
#
# India:
#
#   NON_RECURSIVE:
#     LOCO RMSE:    507.2014
#     Single RMSE: 479.0020
#     Single Country is 5.9% better
#
#   RECURSIVE:
#     LOCO RMSE:    958.7371
#     Single RMSE: 1216.1060
#     LOCO is 21.2% better
#
# Mexico:
#
#   NON_RECURSIVE:
#     LOCO RMSE:    180.3699
#     Single RMSE: 163.9475
#     Single Country is 10.0% better
#
#   RECURSIVE:
#     LOCO RMSE:    306.8340
#     Single RMSE: 140.4960
#     Single Country is 118.4% better
#
# Indonesia:
#
#   NON_RECURSIVE:
#     LOCO RMSE:    262.4916
#     Single RMSE: 338.9329
#     LOCO is 22.6% better
#
#   RECURSIVE:
#     LOCO RMSE:    339.2793
#     Single RMSE: 367.0666
#     LOCO is 7.6% better
#
# Turkey:
#
#   NON_RECURSIVE:
#     LOCO RMSE:    112.3281
#     Single RMSE: 110.6412
#     Single Country is 1.5% better
#
#   RECURSIVE:
#     LOCO RMSE:    218.2190
#     Single RMSE: 147.0159
#     Single Country is 48.4% better
#
# Saudi Arabia:
#
#   NON_RECURSIVE:
#     LOCO RMSE:    381.1656
#     Single RMSE: 392.2408
#     LOCO is 2.8% better
#
#   RECURSIVE:
#     LOCO RMSE:    510.1363
#     Single RMSE: 1131.1158
#     LOCO is 54.9% better
#
# South Africa:
#
#   NON_RECURSIVE:
#     LOCO RMSE:    66.6892
#     Single RMSE: 58.4837
#     Single Country is 14.0% better
#
#   RECURSIVE:
#     LOCO RMSE:    124.0775
#     Single RMSE: 96.4438
#     Single Country is 28.7% better
#
# Argentina:
#
#   NON_RECURSIVE:
#     LOCO RMSE:    76.2844
#     Single RMSE: 106.5726
#     LOCO is 28.4% better
#
#   RECURSIVE:
#     LOCO RMSE:    78.7080
#     Single RMSE: 232.0570
#     LOCO is 66.1% better
# Total rows in summary: 96
#          Data_Type      Strategy   Model Target Country_Group   Avg_RMSE  Avg_MASE
# All Country (LOCO) Non-Recursive Bi-LSTM    Co2     Developed 331.111614  4.271735
#     Single Country Non-Recursive Bi-LSTM    Co2     Developed  70.342134  1.865625
# All Country (LOCO)     Recursive Bi-LSTM    Co2     Developed 423.065130  5.960617
#     Single Country     Recursive Bi-LSTM    Co2     Developed 124.889101  2.853011
# All Country (LOCO) Non-Recursive     CNN    Co2     Developed 160.353315  2.076718
#     Single Country Non-Recursive     CNN    Co2     Developed  60.170766  1.382481
# All Country (LOCO)     Recursive     CNN    Co2     Developed 397.215755  3.841612
#     Single Country     Recursive     CNN    Co2     Developed  65.928376  2.029632
# All Country (LOCO) Non-Recursive ED-LSTM    Co2     Developed  83.837542  2.120722
#     Single Country Non-Recursive ED-LSTM    Co2     Developed 100.962466  2.740234
# Single Country: 39/48 (81.2%)
# LOCO: 9/48 (18.8%)
#
# Average improvement when LOCO wins: 32.64%
# Average improvement when Single Country wins: 154.53%
